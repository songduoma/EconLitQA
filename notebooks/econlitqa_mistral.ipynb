# %%
import os
import pandas as pd
import re
import torch
import transformers
import subprocess
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
from langchain.llms import HuggingFacePipeline
from langchain_huggingface import HuggingFaceEmbeddings
from langchain.prompts import PromptTemplate
from sklearn.preprocessing import MultiLabelBinarizer
from sentence_transformers import SentenceTransformer, util
from sklearn.metrics import precision_score, recall_score, f1_score
from langchain_openai import ChatOpenAI

from langchain.vectorstores import FAISS
device = 'cuda' if torch.cuda.is_available() else 'cpu'

print("Device:", device)
if device == 'cuda':
    print(torch.cuda.get_device_name(0))
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Device: cuda
# NVIDIA RTX A6000

# %%
# !nvidia-smi
# Out:
# Fri Dec 27 18:41:03 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.90.07              Driver Version: 550.90.07      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA RTX A6000               Off |   00000000:3B:00.0 Off |                  Off |
# | 30%   31C    P8             22W /  300W |    4428MiB /  49140MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  NVIDIA RTX A6000               Off |   00000000:AF:00.0 Off |                  Off |
# | 30%   31C    P8             17W /  300W |    4954MiB /  49140MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   2  NVIDIA RTX A6000               Off |   00000000:D8:00.0 Off |                  Off |
# | 30%   40C    P8             24W /  300W |    9928MiB /  49140MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A   1029648      C   /usr/bin/python3                             4412MiB |
# |    0   N/A  N/A   1178934      G   /usr/lib/xorg/Xorg                              4MiB |
# |    1   N/A  N/A   1029648      C   /usr/bin/python3                             4938MiB |
# |    1   N/A  N/A   1178934      G   /usr/lib/xorg/Xorg                              4MiB |
# |    2   N/A  N/A   1029648      C   /usr/bin/python3                             9912MiB |
# |    2   N/A  N/A   1178934      G   /usr/lib/xorg/Xorg                              4MiB |
# +-----------------------------------------------------------------------------------------+

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "2"

# %%
'''# Huggingface libraries to run LLM.
# !pip install -q -U transformers
# !pip install -q -U accelerate
# !pip install -q -U bitsandbytes
# !pip install -q -U huggingface_hub

#LangChain related libraries
# !pip install -q -U langchain
# !pip install -q -U langchain-community


#Python framework for state-of-the-art sentence, text and image embeddings.
# !pip install -q -U sentence-transformers

# Vector Databses specific Libraries
# !pip install -q -U faiss-gpu

# !pip install torch torchvision torchaudio -i https://pypi.tuna.tsinghua.edu.cn/simple'''
# Out:
# '# Huggingface libraries to run LLM.\n!pip install -q -U transformers\n!pip install -q -U accelerate\n!pip install -q -U bitsandbytes\n!pip install -q -U huggingface_hub\n\n#LangChain related libraries\n!pip install -q -U langchain\n!pip install -q -U langchain-community\n\n\n#Python framework for state-of-the-art sentence, text and image embeddings.\n!pip install -q -U sentence-transformers\n\n# Vector Databses specific Libraries\n!pip install -q -U faiss-gpu\n\n!pip install torch torchvision torchaudio -i https://pypi.tuna.tsinghua.edu.cn/simple'

# %%
with open("password.txt") as f:
    hf_token = f.read()
subprocess.run(["huggingface-cli", "login", "--token", hf_token], check=True)

# %%
origin_model_path = "mistralai/Mistral-7B-Instruct-v0.2"
#"meta-llama/Meta-Llama-3.1-8B-Instruct"

# 配置BitsAndBytes的設定，用於模型的量化以提高效率。
bnb_config = BitsAndBytesConfig \
              (
                load_in_4bit=True,# 啟用4位元量化
                bnb_4bit_use_double_quant=True, # 計算時使用的數據類型
                bnb_4bit_quant_type="nf4", # 量化類型
                bnb_4bit_compute_dtype=torch.bfloat16,# 使用雙重量化
              )
# 定義模型ID，用於從HuggingFace Hub加載模型。
model = AutoModelForCausalLM.from_pretrained (origin_model_path, trust_remote_code=True,
                                              quantization_config=bnb_config,
                                              device_map="auto" ) # 自動選擇運行設備
# 加載並配置模型，這裡使用了前面定義的量化配置。
tokenizer = AutoTokenizer.from_pretrained(origin_model_path)
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
text_generation_pipeline = transformers.pipeline(
    model=model,
    tokenizer=tokenizer,
    task="text-generation",
    eos_token_id=tokenizer.eos_token_id,
    pad_token_id=tokenizer.eos_token_id,
    repetition_penalty=1.2,
    return_full_text=False,
    max_new_tokens= 4096,
    temperature = 0.3,
    do_sample = True,
)

mistral_llm = HuggingFacePipeline(pipeline=text_generation_pipeline)
# Out:
# /tmp/ipykernel_1029719/2688518719.py:14: LangChainDeprecationWarning: The class `HuggingFacePipeline` was deprecated in LangChain 0.0.37 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFacePipeline``.
#   mistral_llm = HuggingFacePipeline(pipeline=text_generation_pipeline)

# %%
with open('thesis_output.txt', 'r', encoding='utf-8') as file:
    content = file.read()
    print(len(content))
    print(content[:100])
    
with open("apikey.txt", 'r', encoding='utf-8') as file:
    key = file.read()
os.environ["OPENAI_API_KEY"] = key
# Out:
# 1244964
# 經濟論文的文章：
# 原文題目：權衡性貨幣回饋法則：以台灣為例 作者：沈中華(Chung-Hua Shen)；徐千婷(Sarah Chien-ting Hsu) 來源：《經濟論文》28卷4期(2000/1

# %%
#套件版本
#text_splitter = RecursiveCharacterTextSplitter(chunk_size=1500, chunk_overlap=100, separators="###")
#chunked_docs = text_splitter.split_text(content)
#客製版本
chunked_docs = content.split("###")

# %%
openai_llm = ChatOpenAI(model="gpt-4o")

# %%
#embeddings_model = HuggingFaceEmbeddings(model_name="sentence-transformers/paraphrase-multilingual-mpnet-base-v2")
embeddings_model = HuggingFaceEmbeddings(model_name="intfloat/multilingual-e5-large")
#embeddings_model = HuggingFaceEmbeddings(model_name="maidalun1020/bce-embedding-base_v1")
db = FAISS.from_texts(chunked_docs, embeddings_model)

# %%
def keyword_extraction(input):
    # 1. 第一階段：提取關鍵字
    keyword_extraction_prompt = PromptTemplate(
        input_variables=["query"],
        template="""
        假設你是一位專業助手，請仔細閱讀以下問題。如果有人要根據這些問題來檢索經濟學論文，請給出三個以下可以幫助找到相關論文的核心關鍵字，並按照編號列出，請不要提供題目沒有提到的關鍵字。

        舉例來說：
        問題：
        假設你是一位經濟學領域的研究者，請根據提供的的資料，分析行為經濟學中決策理論的應用，並根據提供的資料提出可能的研究方向。**請用繁體中文回答**

        關鍵字：
        1. 行為經濟學
        2. 決策理論

        問題：
        假設你是一位經濟學領域的研究者，請根據提供的的資料，觀察有關最低工資政策對就業影響的研究，並找出相關的研究熱點。**請用繁體中文回答**

        關鍵字：
        1. 最低工資
        2. 就業影響

        問題：
        假設你是一位經濟學領域的研究者，請根據提供的的資料，分析環境經濟學中碳排放交易市場的研究現況，並找出相關文章的研究熱點。**請用繁體中文回答**

        關鍵字：
        1. 環境經濟學
        2. 碳排放交易

        問題：
        假設你是一位經濟學領域的研究者，請根據提供的的資料，分析貿易保護政策對全球供應鏈的影響，並根據資料找出核心研究方向。**請用繁體中文回答**

        關鍵字：
        1. 貿易保護
        2. 全球供應鏈

        現在換你回答：
        問題：
        {query}

        關鍵字：
        """
        )   


    keyword_chain = keyword_extraction_prompt | mistral_llm


    # 提取關鍵字
    query = "假設你是一位經濟學領域的學者，請根據提供的的資料，"
    query += input
    query += '**請用繁體中文回答**'
    keywords = keyword_chain.invoke({"query": query}).strip()

    keywords_list = re.findall(r"\d+\.\s*(.+)", keywords)
    # 移除中文和英文字符，只保留非中文、非英文字符
    cleaned_keywords = []
    for keyword in keywords_list:
        cleaned_keyword = re.sub(r"[^\u4e00-\u9fa5]", "", keyword) 
        cleaned_keywords.append(cleaned_keyword)

    # 用頓號將清理過後的關鍵字連接
    formatted_keywords = " ".join(cleaned_keywords[:3])
    return formatted_keywords, query

def retrieve(formatted_keywords):
    # 2. 第二階段：檢索相關 chunks
    retriever = db.as_retriever(search_type="similarity_score_threshold", search_kwargs={"score_threshold": 0.7, "k": 20})
    retrieved_docs = retriever.invoke(formatted_keywords)
    retrieved_content = "\n".join([doc.page_content for doc in retrieved_docs])
    #print("Retrieved Documents:")
    #for i, doc in enumerate(retrieved_docs):
    #    print(f"{i+1}. {doc.page_content}...") 
    return retrieved_content

def final_qa(keywords, retrieved_content, query):
    # 3. 第三階段：生成最終答案
    final_prompt_template = PromptTemplate(
        input_variables=["keywords", "retrieved_content", "query"],
        template="""
        假設你是一位經濟學領域的學者。以下是根據檢索關鍵字 "{keywords}" 從資料庫中獲取的相關內容，若有跟問題無關之資料，請忽略它：

        {retrieved_content}

        請根據以上內容回答以下問題：
        {query}
        若文件中無法找到相關資訊，則請務必回覆「資訊不足」。另外，也不要生成不存在的文獻，僅提供實際存在的學術研究。
        **請務必使用繁體中文回答。**
        """
    )

    final_qa_chain = final_prompt_template | mistral_llm
    response = final_qa_chain.invoke({"keywords": keywords, "retrieved_content": retrieved_content, "query": query})
    return response

# %%
inputs = ["請幫我找到入學管道這個主題相關的論文中找出最常出現的學術期刊或出版單位，並分析這些來源的影響力。",
         "請幫我找到入學管道這個主題最常使用的關鍵字，並推測這些關鍵字可能的研究熱點。",
         "請幫我以入學管道這個主題的相關文章綜合關鍵字、摘要和來源，是否能觀察到這個主題的研究熱點或趨勢。",
         "幫我觀察哪些作者在入學管道這個主題發表的文章最多",
         "幫我寫一篇有關入學管道的文獻回顧。"]

keywords = []
querys = []
retrieved_contents = []
responses =[]
for i in range(5):
    keyword, query = keyword_extraction(inputs[i])
    print(f"{i + 1}.")
    print("query:", query)
    print("keywords", keyword)
    retrieved_content = retrieve(keyword)
    response = final_qa(keyword, retrieved_content, query)
    print("Final Answer:")
    print(response)   
    keywords.append(keyword)
    querys.append(query)
    retrieved_contents.append(retrieved_content)
    responses.append(response)
# Out:
# Starting from v4.46, the `logits` model output will have the same type as the model (except at train time, where it will always be FP32)
# 1.
# query: 假設你是一位經濟學領域的學者，請根據提供的的資料，請幫我找到入學管道這個主題相關的論文中找出最常出現的學術期刊或出版單位，並分析這些來源的影響力。**請用繁體中文回答**
# keywords 入學管道 學術期刊出版單位 入學管道
# Final Answer:
# 根據提供的資料，可以從經濟論文叢刊、人文與社會科學集刊、應用經濟論叢等學術期刊中找到有關入學管道的研究。其中，經濟論文叢刊似乎是最常出現的學術期刊，它有很多文章涉及入學管道的研究，例如「大學入學管道與學業表現」、「入學管道與學習表現」等文章。這些文章通常被引用很多次，因此，經濟論文叢刊在入學管道研究中的影響力很大。人文與社會科學集刊也有一些文章關於入學管道，但它們的影響力可能比經濟論文叢刊少一些，因為這些文章通常被引用次数少一些。應用經濟論刊也有一些文章關於入學管道，但它們的影響力可能比人文與社會科學集刊還少一些，因為它們通常被引用次数最少。總的來說，經濟論文叢刊是入學管道研究中最常见的学术期刊，它们的影响力很大，因为这些文章经常被引用很多次。
# 2.
# query: 假設你是一位經濟學領域的學者，請根據提供的的資料，請幫我找到入學管道這個主題最常使用的關鍵字，並推測這些關鍵字可能的研究熱點。**請用繁體中文回答**
# keywords 入學管道 學生招收 上學路径
# Final Answer:
# 根據提供的資料，入學管道是一個很常見的研究題目，常見的關鍵字包括「多元入學」、「個人申請」、「指考」、「高中畢業學校」、「學業成績」、「家庭背景」、「教育政策」等。這些關鍵字可能代表不同的研究角度，例如「多元入學」可能代表研究不同入學管道對學生表現的影響，「個人申請」可能代表研究家庭背景對入學管道選擇的影響，「高中畢業學校」可能代表研究不同高中畢業學校對入學管道選擇的影響，「學業成績」可能代表研究學業成績對入學管道選擇的影響，「家庭背景」可能代表研究家庭背景對入學管道選擇的影響，「教育政策」可能代表研究不同教育政策對入學管道的影響。因此，這些關鍵字可能代表不同的研究熱點，例如研究不同入學管道對學生表現的影響、研究家庭背景對入學管道選擇的影響、研究不同高中畢業學校對入學管道選擇的影響、研究學業成績對入學管道選擇的影響、研究不同教育政策對入學管道的影響等。
# 3.
# query: 假設你是一位經濟學領域的學者，請根據提供的的資料，請幫我以入學管道這個主題的相關文章綜合關鍵字、摘要和來源，是否能觀察到這個主題的研究熱點或趨勢。**請用繁體中文回答**
# keywords 入學管道 經濟學
# Final Answer:
# 以下是您可能需要的相關關鍵字：入學管道、個人申請、指考、高中畢業學校、學業表現、家庭經濟背景、弱勢家庭、弱勢學生、教育改革、教育機會、代際所得流動、反向所得重分配、招生機制、日期決策競爭、頂尖大學、學校品質、父母資源、學生教育成就產出、教育生產函數、學校資源、高中。
#
#         通過上述文章，我們可以發現研究員在研究入學管道方面，常常關注以下幾個方面：
#         1. 入學管道與學業表現之間的關係，例如李維彪等人（2020/03）的研究，他們使用台大生的學籍資料、入學考試成績和在學成績，探討不同管道學生入學後的學業表現差異，並評估多元入學政策在台大實施的成效。
#         2. 家庭經濟背景與入學管道之間的關係，例如施琇涵（2024/03）的研究，她利用東海大學資料，檢視學生家庭經濟背景與大學入學管道之間的關係。
#         3. 入學管道與學校品質之間的關係，例如蔡彣涓（2012/12）的研究，他使用2001-2003年的大學聯招考生成績檔，研究高中應屆考生教育生產函數中各種投入的相對重要性及其成效，並使用各高中的師生比衡量學校的財wealth資源、各高中應屆考生大學學測的平均成績衡量學校聲譽的投入、補習費用衡量父母財wealth資源的投資，且估計各投入對學生大學指定科目考試成績的影響。
#         4. 入學管道與教育改革之間的關係，例如駱明慶等人（2004/12）的研究，他探討家庭背景對個人升學機率的影響，如何隨著整體就學機會的增加而變化。
#         5. 入學管道與招生機制之間的關係，例如高一誠等人（2017/09）的研究，他針對考試結果之不確定性，研究不同類型學校間考期的錯開現象。
#         6. 入學管道與反向所得重分配之間的關係，例如沈暉智等人（2019/09）的研究，他探討家戶所得及資產對子代教育取得之機會，並檢視政府對公私立學校補助的差異，這是一種反向的所得重分配。
#         7. 入學管道與代際所得流動之間的關係，例如鄭保志（2020/12）的研究，他探討學生在遊戲教學模式下學習經濟學的成效，並發現遊戲教學會讓學生對《經濟學》產生較正面的態度，並在短期學習成效方面和中長期記憶方面都有顯著優勢。
#         以上是入學管道相關研究的一些方向，這些研究可以帮助我们深入了解入學管道的影響，並為教育政策提供依据。
# 4.
# query: 假設你是一位經濟學領域的學者，請根據提供的的資料，幫我觀察哪些作者在入學管道這個主題發表的文章最多**請用繁體中文回答**
# keywords 入學管道 作者
# Final Answer:
# 根據提供的資料，駱明慶作者在入學管道這個主題發表的文章最多，共有七篇文章。
# 5.
# query: 假設你是一位經濟學領域的學者，請根據提供的的資料，幫我寫一篇有關入學管道的文獻回顧。**請用繁體中文回答**
# keywords 入學管道 經濟學 文獻回顧
# Final Answer:
# 您可以按照以下格式回答：
#         1. 研究題目：
#         2. 研究方法：
#         3. 研究結果：
#         4. 研究意義：
#         5. 注意事项：
#         6. 參考文獻：
#
#         1. 研究題目：本研究旨在探討不同入學管道對台大學生入學後學業表現的差畫，並評估多元入學政策在台大實施的成效。
#         2. 研究方法：本研究使用2007-14年間入學之台大學生的學籍資料、入學考試成績和在學成績，通過統計分析和回归分析等方法，探討不同管道學生入學後的學業表現差畫，並藉此評估多元入學政策在台大實施的成效。
#         3. 研究結果：本研究發現，以個人申請管道入學學生的學業成績顯著優於透過指考入學的學生，但學測成績的差畢即可解釋兩者入學後學業表現的大部分差畢。控制學測成績後，申請生和指考生的學業成績並没有顯著差畢。在轉系與退學的面向，申請、繁星生无论在转系、成績因素退學和主动退學的比例，皆明显低于指考生。在繁星計畫／繁星推薦方面，繁星生平均的學業表現优于申請生和指考生。这不仅来自明星高中繁星生的貢獻，非明星高中繁星生的學業表現平均而言也顯著高於指考生。但是，如果只看來自2011-15年内无人以申請或指考进入台大的高中的繁星生，其學業成績则顯著低於指考生。此差畢也可以用學測成績的差畢來解釋；控制學測成績後，這些繁星生和指考生的學業成績并沒有顯著差畢。
#         4. 研究意義：本研究對於多元入學政策的實施和效益具有重要意義，為政府和大學管理員提供參考資料，以便更好地實施和改善多元入學政策。
#         5. 注意事項：本研究的統計數據來自台大學的學籍資料和入學考試成績，可能存在一定的漏洞和偏差，需要注意。
#         6. 參考文獻：Lee, W.-L., Koo, H.-W., & Luoh, M.-C. (2020). Entry pipelines and academic performance: An empirical analysis of the effectiveness of multi-entry policies at National Taiwan University. Journal of Economic Psychology, 82, 101119. <https://doi.org/10.1016/j.hecpsy.2019.101119>

# %%
def decompose_to_statements(question, answer):
    decompose_prompt_template = PromptTemplate(
        input_variables=["question", "answer"],
        template="""
        根據以下的問題與回答，請從回答中創建一個或多個具體的陳述（每句話拆分為具體簡短的陳述句），並按照編號列出。
        問題：{question}
        回答：{answer}
        """
    )
    decompose_chain = decompose_prompt_template | openai_llm
    statement = decompose_chain.invoke({"question": question, "answer": answer})
    return statement

# %%
def verify_statements(context, statements):
    verify_prompt_template = PromptTemplate(
        input_variables=["statement", "context"],
        template="""
        考慮以下的上下文與陳述句，判斷每個陳述句是否被上下文中的資訊支持。
        請為每個陳述句判斷正確與否（請只要回答是或否，不要其他解釋），並按照編號列出。
        {statement}
        上下文：{context}
        """
    )
    verify_chain = verify_prompt_template | openai_llm
    bools = verify_chain.invoke({"statement": statements, "context":context})
    return bools

# %%
def calculate_faithfulness_score(context, question, answer):
    statements = decompose_to_statements(question, answer)
    verification = verify_statements(context, statements)  
    true = 0
    false = 0
    for line in verification.content.split("\n"):
        if "是" in line:
            true += 1
        if "否" in line:
            false += 1
    if true + false == 0:
        faithfulness_score = 0
    else:
        faithfulness_score = true / (true + false)
        faithfulness_score = round(faithfulness_score, 3)
    return faithfulness_score

# %%
faithfulness_scores = []
for i in range(5):
    score = calculate_faithfulness_score(retrieved_contents[i], querys[i], responses[i])
    faithfulness_scores.append(score)

for i, score in enumerate(faithfulness_scores, start=1):
    print(f"問題 {i} 的信實度分數：{score}")
# Out:
# 問題 1 的信實度分數：1.0
# 問題 2 的信實度分數：0.727
# 問題 3 的信實度分數：1.0
# 問題 4 的信實度分數：0.6
# 問題 5 的信實度分數：1.0

# %%
def question_generation(answer):
    question_prompt_template = PromptTemplate(
        input_variables=["answer"],
        template="""
        請根據以下答案產生一個對應的問題
        答案：{answer}
        """
    )
    verify_chain = question_prompt_template | openai_llm
    question = verify_chain.invoke({"answer":answer})
    return question

# %%
model = SentenceTransformer('intfloat/multilingual-e5-large')

def calculate_answer_relevance_score(questions, pred_questions):
    embedding1 = model.encode(questions, convert_to_tensor=True)
    embedding2 = model.encode(pred_questions, convert_to_tensor=True)
    relevance_score = util.cos_sim(embedding1, embedding2).item()   
    return relevance_score

# %%
answer_relevance_scores = []
for i in range(5):
    pred_questions = question_generation(responses[i])
    score = calculate_answer_relevance_score(querys[i], pred_questions.content)
    answer_relevance_scores.append(score)

for i, score in enumerate(answer_relevance_scores, start=1):
    print(f"問題 {i} 的answer_relevance分數：{round(score,3)}")
# Out:
# 問題 1 的answer_relevance分數：0.924
# 問題 2 的answer_relevance分數：0.931
# 問題 3 的answer_relevance分數：0.888
# 問題 4 的answer_relevance分數：0.879
# 問題 5 的answer_relevance分數：0.884

# %% [markdown]
# ### test keywords

# %%
data = pd.read_csv("econ_questions_keywords.csv")
print(data.shape)
data.head(5)
# Out:
# (100, 2)
#                         questions         keywords
# 0       從社會保障政策的角度，分析其對貧富差距的潛在影響。      社會保障政策 貧富差距
# 1  請從金融市場波動性的角度，分析其對發展中國家經濟的深遠影響。  金融市場波動性 發展中國家經濟
# 2    請探討全球化影響與教育機會的關聯，並分析文獻中的爭議點。       全球化影響 教育機會
# 3     從歷史與當前數據的角度，分析技術進步對城市居民的影響。        技術進步 城市居民
# 4      從歷史與當前數據的角度，分析數位化對年輕一代的影響。         數位化 年輕一代

# %%
questions = data["questions"]
questions
# Out:
# 0          從社會保障政策的角度，分析其對貧富差距的潛在影響。
# 1     請從金融市場波動性的角度，分析其對發展中國家經濟的深遠影響。
# 2       請探討全球化影響與教育機會的關聯，並分析文獻中的爭議點。
# 3        從歷史與當前數據的角度，分析技術進步對城市居民的影響。
# 4         從歷史與當前數據的角度，分析數位化對年輕一代的影響。
#                    ...
# 95        請分析醫療保健體系如何影響移民工人，並總結政策建議。
# 96      請根據網絡安全的最新研究，探討其對跨國公司的多層次影響。
# 97    描述數位化在不同地區的應用，並分析其對勞動力市場改善的影響。
# 98       從企業社會責任政策的角度，分析其對貧富差距的潛在影響。
# 99       描述自動化在不同地區的應用，並分析其對產業發展的影響。
# Name: questions, Length: 100, dtype: object

# %%
for i in range(1):
    keywords, query = keyword_extraction(questions[i])
    print(f"{i}. questions:", questions[i])
    print("query:", query)
    print("keywords", keywords)
    print("\n")
# Out:
# 0. questions: 從社會保障政策的角度，分析其對貧富差距的潛在影響。
# query: 假設你是一位經濟學領域的學者，請根據提供的的資料，從社會保障政策的角度，分析其對貧富差距的潛在影響。**請用繁體中文回答**
# keywords 社會保障政策 貧富差距

# %%
predicted_keywords = []
for i in range(len(data)):
    llm_generated_keywords, _ = keyword_extraction(data["questions"][i])  # 假設有一個關鍵字提取函數
    predicted_keywords.append(llm_generated_keywords)
    if (i + 1) % 5 == 0:
        print(f"{i + 1} questions are done!")

# 這裡將 true_keywords 和 predicted_keywords 轉換為二進制格式
true_keywords = data["keywords"]
# Out:
# 5 questions are done!
# 10 questions are done!
# 15 questions are done!
# 20 questions are done!
# 25 questions are done!
# 30 questions are done!
# 35 questions are done!
# 40 questions are done!
# 45 questions are done!
# 50 questions are done!
# 55 questions are done!
# 60 questions are done!
# 65 questions are done!
# 70 questions are done!
# 75 questions are done!
# 80 questions are done!
# 85 questions are done!
# 90 questions are done!
# 95 questions are done!
# 100 questions are done!

# %%
# 初始化 SentenceTransformer 模型
model = SentenceTransformer('intfloat/multilingual-e5-large')

adjusted_predicted_keywords = []
for i in range(len(predicted_keywords)):
    adjusted_list = []
    # 將字串轉為列表
    true_kw_list = true_keywords[i].split()
    pred_kw_list = predicted_keywords[i].split()
    # 批量編碼
    true_embeddings = model.encode(true_kw_list, convert_to_tensor=True)
    pred_embeddings = model.encode(pred_kw_list, convert_to_tensor=True)
    for j, pred_kw in enumerate(pred_kw_list):
        # 計算每個 predicted_keyword 與 true_keywords 的相似度
        cos_similarities = util.cos_sim(pred_embeddings[j], true_embeddings).cpu().tolist()
        # 找到相似度最大值
        max_similarity = max(cos_similarities[0])
        if max_similarity > 0.9:
            max_idx = cos_similarities[0].index(max_similarity)
            adjust_kw = true_kw_list[max_idx]
            adjusted_list.append(adjust_kw)
        else:
            adjusted_list.append(pred_kw)
    # 保存結果
    adjusted_predicted_keywords.append(adjusted_list if adjusted_list else [])

# %%
# Convert string format to list format if needed
true_kw_lists = [kw.split() if isinstance(kw, str) else kw for kw in true_keywords]
pred_kw_lists = [kw.split() if isinstance(kw, str) else kw for kw in adjusted_predicted_keywords]

# Get unique keywords from both sets
all_keywords = set()
for kw_list in true_kw_lists + pred_kw_lists:
    all_keywords.update(kw_list)

# Create binary vectors
mlb = MultiLabelBinarizer(classes=list(all_keywords))
y_true = mlb.fit_transform(true_kw_lists)
y_pred = mlb.transform(pred_kw_lists)

# Calculate metrics
metrics = {
    'precision': precision_score(y_true, y_pred, average='micro'),
    'recall': recall_score(y_true, y_pred, average='micro'),
    'f1': f1_score(y_true, y_pred, average='micro'),
}


# Create a formatted results dataframe
results_df = pd.DataFrame({
    'Metric': list(metrics.keys()),
    'Score': list(metrics.values())
})

results_df
# Out:
#       Metric     Score
# 0  precision  0.815686
# 1     recall  0.967442
# 2         f1  0.885106

# %% [markdown]
# ### test faithfulness

# %%
keywords = []
querys = []
retrieved_contents = []
responses =[]
for i in range(len(questions)):
    keyword, query = keyword_extraction(questions[i])
    print(f"{i + 1}.")
    print("query:", query)
    print("keywords", keyword)
    retrieved_content = retrieve(keyword)
    response = final_qa(keyword, retrieved_content, query)
    print("Final Answer:")
    print(response)   
    keywords.append(keyword)
    querys.append(query)
    retrieved_contents.append(retrieved_content)
    responses.append(response)
# Out:
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# 1.
# query: 假設你是一位經濟學領域的學者，請根據提供的的資料，從社會保障政策的角度，分析其對貧富差距的潛在影響。**請用繁體中文回答**
# keywords 社會保障政策 貧富差距
# Final Answer:
# 您的回答應包括以下幾點：
#         1. 提供相關研究文獻標題及作者姓名，以便讓讀者了解您的研究基础。
#          2. 描述研究內容，包括研究方法、結果及對貧富差距的影響。
#          3. 分析研究結果對貧富差距的潛在影響，並引用相關研究文獻來支持您的分析。
#
#         以下是您的回答：
#          Based on the provided data, as an economist specializing in social security policies, I will analyze the potential impact of these policies on income inequality from a social welfare perspective based on the following studies:
#
#          1. Title: The Impact of Social Welfare Policies on Income Inequality in Taiwan: A Panel Data Analysis
#             Authors: Chih-Hsin Chiang and Meng-Lung Yang
#
#          2. This study examines the relationship between various types of social welfare programs (including public pensions, unemployment insurance, and healthcare subsidies) and income inequality using panel data analysis for the period of 1992 to 2010 in Taiwan. The results show that social welfare policies have had a significant negative effect on reducing income inequality. Specifically, public pension schemes and healthcare subsidies were found to be particularly effective in mitigating income disparities.
#
#          3. Another relevant research is titled: "The Effectiveness of Universal Basic Income in Reducing Income Inequality: Evidence from Taiwan's New Pension System." Author: Jia-Ru Li. This paper investigates the redistributive effects of the new pension system introduced in Taiwan in 1995, which included universal coverage and a flat-rate benefit structure. The findings suggest that this policy reform significantly reduced income inequality by providing a basic safety net for all citizens regardless of their income levels.
#
#          4. My analysis builds upon these studies and argues that well-designed social welfare policies can effectively contribute to narrowing the income gap. By ensuring adequate financial resources for low-income households, such policies help address the root causes of poverty and reduce the overall level of income inequality within society. For instance, the implementation of comprehensive social welfare programs, including universal health care, affordable housing initiatives, and education subsidies, could potentially lead to more equitable distribution of resources and opportunities among different socioeconomic groups. Furthermore, progressive taxation systems and targeted cash transfer programs can further enhance the redistributive impact of social welfare policies. Overall, my interpretation aligns with the existing literature emphasizing the importance of social welfare policies in promoting greater income equality and social cohesion.
# 2.
# query: 假設你是一位經濟學領域的學者，請根據提供的的資料，請從金融市場波動性的角度，分析其對發展中國家經濟的深遠影響。**請用繁體中文回答**
# keywords 金融市场 波动性 发展中国家经济
# Final Answer:
# 您可以按照以下順序回答問題：
#          1. 描述文件中的研究內容和結果。
#          2. 分析文件中的研究結果對發展中國家經濟的影響。
#          3. 提出一些建議或想法，以便更深入地研究這個話题。
#
#         1. 文件中有幾篇研究探討金融市場波動性對發展中國家經濟的影響，例如：「資金流動、國際金融整合與經濟成長：東歐、東亞與拉丁美洲新興市場地區的實證分析」、「美國股市及其總體經濟變數間關連性與波動性之研究」等。這些研究探討了金融市場波動性對新興市場地區國家的影響，並提出了不同的結论。例如，東歐國家的資金流動方向將由資金流入轉爲流出，但這對經濟成長的影響尚未明確；東亞國家的超額儲蓄、貿易出超與資金流出被指控造成美國巨額經常帳赤字與全球經常帳失衡的主因之一，但若能持續金融深化的努力，資金可能回流並使全球經常帳失衡現象得以緩和。拉丁美洲國家的總體經濟、金融和政策特徵狀態變數對於資金流動方向並無決定性影響，但財政與貨幣政策紀律仍是決定資金流入能否有助於經濟成長的主要關鍵。
#         第四，經濟論文的文章 "[教育配額、累進稅和長期產出]" (Education Quotas, Progressive Taxes, and Long-term Output) by Jing-Jun Chang discusses the potential benefits of using education quotas and progressive taxes to promote long-term economic growth. The author argues that these policies can help ensure that high-ability students receive a quality education, which in turn leads to increased productivity and innovation.
#         第五，中國大陸研究的文章 "[全球化之下中國大陸研究生教育的發展與轉型]" (Development and Transformation of Doctoral Education in China under Globalization) by Juei-Chi Wang analyzes the impact of globalization on doctoral education in China. The article notes that globalization has led to increased collaboration between Chinese and foreign universities, as well as the emergence of new research fields and interdisciplinary approaches. However, the author also warns of the potential pitfalls of relying too heavily on foreign expertise and neglecting domestic talent development.
#         第六，經濟論文叢刊的文章 "[教育配額、學費和勞動供給]" (Education Quotas, School Fees, and Labor Supply) by Chi-Foon Lee and Yee Kwok Chet explore the relationship between education quotas, school fees, and labor supply in Hong Kong. The study finds that increasing education quotas and reducing school fees can lead to an increase in the number of students pursuing higher education, which in turn affects labor supply and wages.
#         第七，文化創意產業研究學報的文章 "[教育配額、補習和社會流動]" (Education Quotas, Tutoring, and Social Mobility) by Jing-Jun Chang discusses the impact of education quotas, tutoring, and social mobility on upward intergenerational mobility in Taiwan. The study finds that while education quotas and tutoring can provide opportunities for disadvantaged students to attend prestigious universities, they do not necessarily guarantee success in achieving upward social mobility.
#         在這些文獻中，有一些爭議點值得注意。首先，有些研究表明，全球化造成了新的教育機會，例如增加了跨國學生交流和idea exchange。然而，其他研究警告全球化可能會擴大educational disparities，例如，那些沒有足夠的資源和oppurtunity的人士可能無法享受良好的教育。其次，有些研究强調了language skills和cultural exposure的重要性在全球化中，而其他研究则注意到，這些factors可能對某些group disproportionately，例如female or low-SES students。最後，有些研究強調了government policy和institutional changes的重要性在全球化中，而其他研究則注意到，這些changes可能會造 succes stories but also create losers。
#         總的來说，這些文獻表明了全球化對教育機會的複雜影響，并提供了一些Insights into how different factors interact to shape educational outcomes in a globalized world. These insights can be useful for policymakers, educators, and researchers seeking to understand and address the challenges and opportunities presented by globalization in the realm of education.
# 4.
# query: 假設你是一位經濟學領域的學者，請根據提供的的資料，從歷史與當前數據的角度，分析技術進步對城市居民的影響。**請用繁體中文回答**
# keywords 技術進步 城市居民 企業管理模式
# Final Answer:
# 您好！根據提供的文章，我們可以從中國大陸各地方政府近年來的試圖強化回應民眾之措施中，了解中共在建立對公眾的回應性的涵義。這些文章描述了武漢市的「行風連線」網站，該網站是近年該市監察局建立的意見反映電子網路平台，用於受理相關政府機關及公用事業政風行風問題的舉報投訴、政策諮詢和意見建議。被針對單位必須直接且限期回應民眾所提出的問題或舉報，民眾張貼的內容及相關單位的答覆皆公開於網站，投訴人並可以針對所收到的回覆給予滿意度評價。這個平台可以讓城市居民更closely engage with their government and hold them accountable for their actions. This is a positive step towards improving responsiveness to citizens' needs and concerns in China.
#         從歷史上來說，中共在建國以來的政治歷史很大部分是圓繞著如何打擊「官僚主義」這個問題。「官僚主義」代表著幹部脫離群眾的問題。在毛澤東時代，中共理解官僚主義是受資產階級和封建主義思想餘毒影響所產生的問題，必須透過由上而下的思想教育、下放勞動及發動群眾由下而上進行監督這種「三明治方式」來進行整治。但在改革開放時代，中共已不再強調意識形態鬥爭，群眾運動也逐漸退卻。中共開始傾向以由上而下的「管理」及「有秩序引導」模式來整治官僚問題。但群眾並没有被排除在外，新的「群眾路線」正成為中共監督官僚機制的一部分。最終結合形成一種「新三明治式」的官僚控制模式。
#         從当前数据来说，这种平台可以帮助城市居民更 closely engage with their government and hold them accountable for their actions. It is a positive step towards improving responsiveness to citizens' needs and concerns in China. According to statistics from the Ministry of Public Security, there were over 2 million reports submitted through these platforms between January 2015 and December 2016. Of these reports, about 80% related to administrative issues such as urban management, traffic violations, and public services, while the remaining 20% related to more serious issues such as corruption, abuse of power, and social unrest. These numbers suggest that this type of platform can be an effective tool for addressing citizen complaints and promoting transparency and accountability in Chinese governance.
#         總之，從歷史與當前數據的角度來看，技術進步對城市居民的影響是使他們能够更 closely engage with their government and hold them accountable for their actions. This is a positive development towards improving responsiveness to citizens' needs and concerns in China. However, it is important to note that this is just one aspect of technological progress and its impact on city residents. Other factors, such as job displacement due to automation or access to digital technologies, may also have significant effects on urban populations. Therefore, further research is needed to fully understand the complex ways in which technology is shaping the lives of city dwellers in China.
# 5.
# query: 假設你是一位經濟學領域的學者，請根據提供的的資料，從歷史與當前數據的角度，分析數位化對年輕一代的影響。**請用繁體中文回答**
# keywords 数字化 年轻一代 历史与当前数据
# Final Answer:
# 您可以按照以下順序回答問題：
#          1. 描述中國近年來政策層面對大型資訊服務提供業者和平臺服務的法律監管體系。
#          2. 分析中國如何以法令作為鞏固國家優越地位的政策工具，並協助公權力控管資通場域。
#          3. 討論中國對大型網路平臺與個人用戶所牽動之三角關係的轉變。
#          4. 描述中國近年來對防疫健康碼和通信大數據行程卡的使用，以及它們對中國威權國家的能力增强的影響。
#          5. 討論中國對新教倫理的現实意涵，以及它對今日社會的影響。
#          6. 分析中國少子化對策的演化，以及它對社會與經濟的影響。
#          7. 描述台灣男性勞動市場參與之研究，以及它對台灣經濟 loops 的影響。
#          8. 討論台灣階級與世代的收入差畢，以及它對台灣社會的影響。
#          9. 描述中國大陸媒體在數位時代的轉型，以及它對中國media 的影響。
#          10. 分析臺灣稻作經濟下的創新與尋租，以及它對少子化問題的影響。
# 6.
# query: 假設你是一位經濟學領域的學者，請根據提供的的資料，探討勞動法對於老年人口與環境可持續性的長期影響。**請用繁體中文回答**
# keywords 勞動法 老年人口 環境可持續性
# Final Answer:
# 您好！根據提供的資料，我們可以從兩方面探討勞動法對於老年人口與環境可持續性的長期影響：
#         第一，勞動法對於老年人口的長期影響。根據「台灣經濟預測與政策」中的文章[1]，我們可以看出，勞動法對於老年人口有著重要的影響，因為它直接影響老年人的勞動參与率和工資水平。如果勞動法能夠促進老年人的勞動參與，並保證他們的工資水平，那么這將有助於減少老年人的生活困难，並提高他們的生活水平。此外，如「人文與社會科學集刊」中的文章[2]所示，勞動法對於老年人的健康状况也有著重要的影響，因为健康状况对于老年人的经济参与和社会生活都是关键因素。
#         第二，勞動法對於環境可持續性的長期影響。根据「台灣經濟預測與政策」中的文章[3]，我们可以看出，勞動法也可以从长远的角度影响环境可持续性。例如，勞動法可以规定某种产业或职业对环境造成的污染程度，并强制这些单位采取措施减轻污染。此外，勞動法还可以促进员工参与环保行动，并提供相应奖励或补贴。这将有助于促进企业和个人采取环保措施，从而促进環境可持續性。
#         总之，勞動法在長期的角度上對於老年人口和環境可持續性都有著重要的影響，而且這些影響可以相互促進。
#         關鍵字：勞動法, 老年人口, 環境可持續性
#
#         參考文獻：
#         1. 李建良(Chien-Liang Lee), 代際正義的法律課題: 作者：李建良(Chien-Liang Lee), 來源：《臺灣經濟預測與政策》46卷2期(2016/03)Pp. 209-242.
#         2. 林倩如(Chien-ju Lin), 從累積的社會結構理論看臺灣勞動政策的制定與施行: 以《大量解僱勞工保護法》為例: 作者：林倩如(Chien-ju Lin), 來源：《人文及社會科學集刊》36卷1期(2024/03)Pp. 245-290.
#         3. 許耿銘(Keng-Ming Hsu); 紀駿傑(Chun-Chieh Chi); 蕭新煌(Michael Hsin-Huang Hsiao), 氣候變遷、世代正義與永續性: 概念、指標與政策: 作者：許耿銘(Keng-Ming Hsu); 紀駿傑(Chun-Chieh Chi); 蕭新煌(Michael Hsin-Huang Hsiao), 來源：《臺灣經濟預測與政策》46卷2期(2016/03)Pp. 259-285.
# 7.
# query: 假設你是一位經濟學領域的學者，請根據提供的的資料，請根據全球化的最新研究，探討其對家庭的多層次影響。**請用繁體中文回答**
# keywords 全球化 家庭 多層次影響
# Final Answer:
# 全球化是今天世界经济发展的一个重要趋势，它对国际贸易、财务、信息等领域产生着广泛的影响。但是，全球化的影响并不仅仅局限于这些领域，还会产生更复杂的影响，特别是对家庭来说。
#         现有研究表明，全球化导致的职业结构变化、资本流动、教育机会等因素，会带来家庭内部关系的变化。例如，全球化导致的技术进步和劳动力市场调节，会让家庭内部分担更多的家庭任务，从而影响家庭组织及家长与儿童间的关系。
#         同时，全球化也会影响家庭的经济状况。例如，全球化导致的贸易自由化和资本流动，会使家庭所有成员获得更多的经济机遇，但同时也会给Family income distribution带来更多的压力，使家庭中有些成员缺乏经济资源，导致家庭内部关系变化。
#         最后，全球化还会影响家庭的文化传承和社会化过程。例如，全球化导致的信息流动和媒体扩散，会使家庭成员接触更多的文化和社会观点，从而影响家庭的文化传承和社会化过程。
#         总之，全球化对家庭的影响是Complex and multifaceted，它会影响家庭内部关系、经济状况和文化传承等方面。为了更好地了解这个问题，需要更多的研究和数据支持。
# 8.
# query: 假設你是一位經濟學領域的學者，請根據提供的的資料，請探討人工智慧與企業績效的關聯，並分析文獻中的爭議點。**請用繁體中文回答**
# keywords 人工智慧 企業績效
# Final Answer:
# 人工智慧是什麼？它如何影響企業績效？文獻中有哪些研究探討了這方面的問題？
#         人工智慧（Artificial Intelligence, AI）是一種使用電腦程序模拟、自動化、學習和決策的技術。它可以在各種領域中應用，包括游戏設計、医学、金融等。人工智慧在企業中的應用可以幫助提高生產效率、減少錯誤和提高客戶服務质量。
#         在文獻中，有許多研究探討了人工智慧與企業績effect之間的關聯。以下是一些相關文章：
#         1. 王焜潔 (Kun-Chieh Wang). (2012). 人工智慧在遊戲設計應用之探討與實作 - 基於XNA系統平台 [J]. 文化創意產業研究學報, 2(3), 255-276.
#           這文章描述了如何使用人工智慧來實現一個動作遊戲的AI系統，並探討了物件導向的模組化概念和有限狀態機、模糊狀態機和類神經網路等AI技術的應用。
#         从提供的资料来看，企业社会责任（Corporate Social Responsibility，简称 CSR）是一个热门话题，并且在近年来受到广泛关注。这项政策的影响范围不仅限于环境问题，还扩展到社区发展、人权问题等多方面。
#         现有研究显示，企业社会责任政策对总体经济体系的影响是不确定的，但是它可能带来双重红利效应，提高企业价值和社会福利。当企业社会责任支出比例较低时，这种效应更明显。
#         但是，从政策面来说，政府提高免税比例可以诱使企业增加社会责任支出，从而改善社会福利，但是这个政策也让社会福利极大下所需的企业社会责任支出比例大幅提高，使得社会福利极大更难以达成。
#         从长期的视点来看，企业社会责任政策可能对城市居民和社会安全产生积累性的影响。首先，企业社会责任可以帮助改善城市环境质量，减轻城市居民对 pollution 的负担，从而提高居民的生活质量。其次，企业社会责任支出可以推动社区发展，提高社区设施和服务水平，进而增强社区综合能力和社会安全。
#         最后，企业社会责任政策可以促使企业采取更良好的人力资源管理策略，减少职业风险和劳工伤害，提高劳工福利和安全标准，从而减少城市居民的生活安全风险。
#         总之，企业社会责任政策可以从多方面影响城市居民和社会安全，包括环境质量、社区发展和人力资源管理等。这些影响可能是积累性的，从长期的视点来看，企业社会责任政策可以带来积极的社会和经济效益。
# 13.
# query: 假設你是一位經濟學領域的學者，請根據提供的的資料，請描述勞動法在不同經濟體中的應用案例。**請用繁體中文回答**
# keywords 勞動法 不同經濟體
# Final Answer:
# 您好！根據提供的資料，我可以列出以下勞 labour law 在不同經濟體中的應用案例：
#         1. 「台灣經濟預測與政策」一文中，研究了中國農民工和城市勞工之薪資差畢的原因，並使用「RUMiC」追踐資料進行分析。
#         2. 「經濟論文」一文中，研究了典型和非典型全日工作的工資差畢，並考慮勞動者對工時及契約形式的選擇。
#         3. 「經濟論文」一文中，研究了網際網路對個人的勞動供給行為與地區薪資不均度的影響。
#         4. 「農業經濟叢刊」一文中，研究了台灣農漁會信用部相對於其他金融機構之薪資差畢。
#         5. 「經濟論文叢刊」一文中，研究了我國勞工在工作狀態間之流動分析。
#         6. 「經濟研究」一文中，研究了性別薪資差畢，並使用差畢中差畢配對法與三重差畢法進行評估。
#         7. 「經濟論文」一文中，研究了中國農民工和城市居民的薪資差畢，並使用差畢中差畢配對法進行分析。
#         8. 「經濟論文」一文中，研究了垂直產品差畢與經濟整合的福利分析。
#         9. 「經濟論文」一文中，研究了台灣工資函數與工資性別歧視的分量迴歸分析。
#         10. 「應用經濟論叢」一文中，研究了不同匯率制度下之資本移動性、定價行為與福利表現。
#         以上是我所能從資料中找到的勞 labour law 相關研究案例。希望這些案例能夠對您有所帮助。如果您有其他問題，請隨時告訴我。
# 14.
# query: 假設你是一位經濟學領域的學者，請根據提供的的資料，請根據科技創新的最新研究，探討其對工人的多層次影響。**請用繁體中文回答**
# keywords 科技創新 工人影響
# Final Answer:
# 根据给定数据，作为经济学领域的专家，请按照最新的科技创新研究进行探讨，并描述其对工人的多层次影响。**请用繁体中文回答**
#         如果文档中没有相关信息，请务必回复“信息不足”。另外，还请确保仅提供实际存在的学术研究，不要产生不存在的文献。
#         **请务必使用繁体中文回答。**
#         根據提供的資料，作為經濟學領域的學者，請根據最新的科技創新研究，探討其對工人的多層次影響。**請用繁體中文回答**
#         如果所提供的材料中无法找到相关信息，则请务必回复“信息不足”。另外，也请确保仅提供实际存在的学术研究，不要生成不存在的文献。
#         **請務必使用繁體中文回答。**
#          Based on the provided data, as an economist in the field of economics, please discuss the multilayer impacts of the latest scientific innovation research on workers based on the available literature.**Please use traditional Chinese characters to answer.**
#          如果所提供的材料中沒有相關信息，請務必回複“信息不足”。另外，請注意solely provide real existing academic studies rather than generating nonexistent literature。
#          請務必使用繁體中文回答。
#           根據所提供的資料，作為經濟學領域的學者，請根據最新的科技創新研究，探討其對工人的多層次影響。**請用繁體中文回答**
#           如果所提供的材料中無法找到相關信息，請務必回復“信息不足”。另外，請注意僅提供實際存在的學術研究，不要生成不存在的文獻。
#          請務必使用繁體中文回答。
#           根据给定数据，作为经济学领域的专家，请根据最新的科技创新研究探讨其对工人的多层次影响。**请用繁体中文回答**
#           如果所提供的材料中没有相关信息，请务必回复“信息不足”。另外，请注意仅提供实际存在的学术研究，不要生成不存在的文献。
#          请务必使用繁体中文回答。
#           根據提供的資料，作為經濟學領域的學者，請根據最新的科技創新研究，探討其對工人的多層次影響。**請用繁體中文回答**
#           如果所提供的材料中無法找到相關信息，請務必回復“信息不足”。另外，請注意僅提供實際存在的學術研究，不要生成不存在的文獻。
#          請務必使用繁體中文回答。
#            在最新的科技創新研究中，科技創新對工人影響有多層次的表現。首先，科技創新可以創造新的就业机会，使工人有更多的就业选择，从而提高他们的就业机遇和薪资水平。同时，科技創新可以带来技术转型，使工人需要拥有更高级别的技能和知识，从而需要进行更多的职业训练和调整。这种变化可能导致某些工人失业，但同时也可以培养新的技能和知识，使他们适应新的工业需求，从而提高他们的就业价值和薪资水平。
#            其次，科技創新可以带来工业结构的变革，使传统的工业逐渐被新兴的工业所取代。这种变化可能导致某些工人失业，但同时也可以培养新的技能和知识，使他们适应新的工业需求，从而提高他们的就业价值和薪资水平。
#            最后，科技創新可以带来社会结构的变革，使传统的工作模式逐渐被新兴的工作模式所取代。这种变化可能导致某些工人失业，但同时也可以培养新的技能和知识，使他们适应新的社会需求，从而提高他们的就业价值和薪资水平。
#            总之，在最新的科技創新研究中，科技創新对工人影響有多層次的表现，包括提高就业机会和薪资水平、需要进行更多职业训练和调整、培养新的技能和知识以适应新的工业和社会需求等方面。
#            **請注意：以上回答是根據最新的科技創新研究進行的概述，具體研究結果可能有所不同。**
#            **Please note that the above answer is a summary based on the latest technological innovation research, and specific research results may vary.**
#            在最新的科技創新研究中，科技創新對工人影響有多層次的表現。首先，科技創新可以創造新的就業機會，使工人有更多的就業選擇，從而提高他們的就業機會和薪資水平。同時，科技創新可以帶來技術轉型，使工人需要擁有更高級別的技能和知識，從而需要進行更多的職業訓練和調整。這種變化可能導致某些工人失業，但同時也可以培養新的技能和知識，使他們適應新的工業需求，從而提高他們的就業價值和薪資水平。
#            其次，科技創新可以帶來工業結構的變革，使傳統的工業逐漸被新出現的工業所取代。這種變化可能導致某些工人失業，但同時也可以培養新的技能和知識，使他們適應新的工業需求，從而提高他們的就業價值和薪資水平。
#            最後，科技創新可以帶來社會結構的變革，使傳統的工作模式逐漸被新出現的工作模式所取代。這種變化可能導致某些工人失業，但同時也可以培養新的技能和知識，使他們適應新的社會需求，從而提高他們的就業價值和薪資水平。
#            總之，在最新的科技創新研究中，科技創新對工人影響有多層次的表現，包括提高就業機會和薪資水平、需要進行更多職業訓練和調整、培養新的技能和知識以适应新的工業和社會需求等方面。
#            **請注意：上述回答是根據最新的科技創新研究進行的總體概述，具體研究結果可能有所不同。**
#            **Please note that the above answer is a summary based on the latest technological innovation research, and specific research findings may differ.**
# 15.
# query: 假設你是一位經濟學領域的學者，請根據提供的的資料，請從全球化影響的角度，分析其對勞動市場需求的深遠影響。**請用繁體中文回答**
# keywords 全球化 勞動市場需求
# Final Answer:
# 您好！根據提供的文章，我們可以看到全球化對勞動市场需求的深遠影響。在《中國大陸研究》中，作者讓我們了解到大陸自改革開放以來，勞動力市場一直存在許多問題，導致就业政策不斷改變。其中一個關鍵因素是資本資源偏低和勞動力資源過剩的矛盾，這使得中共未來十年發展策略的目標規劃上，在增長優先和就業優先之間，選擇優先是較佳的政策選擇。此外，隱藏失業和顯性失業長期并存，呈現求職者就業難，求才者招工也難的局面。這種情況需要通過加強對勞動力的培訓和再培訓，提高勞動力的適應性，以糾正勞動力市場的結構性失衡，最終提高人力資源的利用效率。
#         在《經濟論文叢刊》中，作者分析台灣製造業勞動份額下跌的原因，認為是全球化後產業偏向資本密集的生產方式和對中國大陸累計投資增加所致。這些與多數文獻之主張「全球化有降低勞動份額」的結论一致，但對中國出口或對中國之外其他地區的累計投资反而對勞動份額有正面影響，與多數文獻的結論不一致。
#         在《人文及社會科學集刊》中，作者分析兩岸服務貿易協議「自然人移動」的勞動市場調控機制，發現臺灣依照「自然人移動」條款所建構的規範，已經形成一種「相對不平衡」的勞動市場調控機制，即兩岸服務貿易協議與現行法令對於中國的跨國企業內部調動人員及履約人士的限制規範相比，相對都比較少。建議政府應該重新檢討兩岸服務貿易協議對於中國的跨國企業內部調動人員及履約人士進入臺灣的規範，使兩岸服務貿易協議朝向臺灣提交世界貿易組織的入會承諾原則趨於一致。
#         總之，全球化對勞動市場需求的影響是複雜的，不僅是對勞動力資源的供求關係造成的Needle effect和Factor price equalization effect，還包括對勞動力市場調控機制的影響、對勞動力素質的影響等。這些影響可能导致勞動力市場結構的失衡，影響勞動力市場需求的深遠影響。
# 16.
# query: 假設你是一位經濟學領域的學者，請根據提供的的資料，請分析數據隱私如何影響非營利組織，並總結政策建議。**請用繁體中文回答**
# keywords 數據隱私 非營利組織 政策建議
# Final Answer:
# 根据给定数据，请分析数字隐私对非营业组织的影响，并总结政策建议。**如果文档中没有相关信息，请务必回复“信息不足”。另外，还不应创造不存在的学术研究，仅提供实际存在的研究。**
#         根据给定内容，我们将会分析数据隐私对非營利組織的影響，并总结政策建議。**如果该内容中无法找到相关信息，请务必回复“信息不足”。另外，还不应生成不存在的学术研究，仅提供实际存在的研究。**
#         根据给定资料，我们将进行数据隐私对非營利组织的影响分析，并总结政策建议。**如果该材料中没有相关信息，请务必回复“信息不足”。另外，还不应产生不存在的学术研究，仅提供现实存在的研究。**
#
#         根據提供的資料，可以看出，有幾篇文章探討了資訊透明度對非營利組織捐款收入之影響。這些研究顯示，資訊透明度對非營利組織捐款收入有顯著的正相關關聯，這意味著，組織愈高資訊透明度，愈多捐款人所獲得的認同，因此其捐款收入愈高。同時，個別控制變數中，網站資訊揭露程度、補助收入及人事費用等變數，也與捐款收入呈顯著正向關聯。
#
#         這些結果顯示，資訊透明度對非營利組織捐款收入有顯著的影響，因此，政策建議是：非營利組織應優先提高資訊透明度，以便更多捐款人獲得認同，从而獲得更多捐款。此外，政府也應強化對非營利組織的資訊透明度要求，以確保公众可以透明地了解組織的捐款情況，並避免潛在的欺詐行為。
#
#         此外，還有一篇文章探討了受限應變數Tobit模型與Double-Hurdle模型之比較，該文章探討了客製化防災資訊的使用意願及願付價格。這些研究顯示，家庭月收入及教育程度越高、年輕族群、所在地地震危害度較高、網路與平面媒體使用者或已知政府公告避難地點的民眾，有較高的參與意願，可為市場開發時或政策推廣時，優先宣傳這些族群。
#
#         政策建議是：政府應優先為年輕族群、高收入人群、高危地區等人群提供客製化防災資訊，以便他們可以在災情發生時快速获悉避難地點，並避免潛在的損失。此外，政府也應強化對客製化防災資訊的研究和開發，以提高其功能和效用，並鼓勵企業和組織投入此领域，以共同推動市場发展和社會福利提高。
# 17.
# query: 假設你是一位經濟學領域的學者，請根據提供的的資料，請從企業社會責任的角度，分析其對貧富差距的深遠影響。**請用繁體中文回答**
# keywords 企業社會責任 貧富差距
# Final Answer:
# 根据给定数据，从企业社会责任的角度分析其对贫富差距的深远影响。
#         如果文档中无法找到相关信息，请务必回复“信息不足”。另外，还不应创造不存在的学术研究，仅提供实际存在的。
#         Based on the provided data, from an enterprise social responsibility perspective, analyze its far-reaching impact on income inequality.
#         If there is insufficient information in the document, please reply with “insufficient information”. Moreover, no fictional research should be generated, only real existing academic studies should be mentioned.
#         根據所提供的資料，從企業社會責任的角度分析其對貧富差距的深遠影響。
#         如果文檔中缺少相關資訊，請回覆“資訊不足”。另外，請勿生成虚构的研究，僅提供實際存在的學術研究。
#
#         以下是您的回答：
#         根據所提供的相關文章，可以發現企業社會責任對貧富差距的影響是複雜的。在一些研究中，企業社會責任表現對貧富差距的影響顯著，例如，企業社會責任表現對公司風險、財務後果、勞動市場等都有影響，這些影響可能會減緩貧富差距的發展。另一方面，有研究指出企業社會責任表現對貧富差距的影響可能是有限的，例如，企業社會責任表現對個人財富的影響可能很小，企業社會責任表現對國家或地區的貧富差距的影響也可能有限。
#         此外，還有一些研究指出企業社會責任表現對貧富差距的影響可能取決於市場結構、政策等因素。例如，在有效的法規框架下，企業社會責任表現可能有助於減少貧富差距，但在不完善的法規框架下，企業社會責任表現可能無法減少貧富差距。此外，企業社會責任表現對貧富差距的影響也可能取決於企業的規模、產業、地區等因素。例如，大型企業可能有更大的社會影響力，因此其社會責任表現可能對貧富差距的影響更大。
#         總的來說，企業社會責任對貧富差距的影響是複雜的，取決於市場結構、政策、企業規模、產業、地區等因素。更多研究 Still more research is needed to fully understand this relationship between enterprise social responsibility and income inequality.
# 18.
# query: 假設你是一位經濟學領域的學者，請根據提供的的資料，請分

# query: 假設你是一位經濟學領域的學者，請根據提供的的資料，從歷史與當前數據的角度，分析自動化對年輕一代的影響。**請用繁體中文回答**
# keywords 自動化 年輕一代 歷史當前數據
# Final Answer:
# 自動化是今天世界上最火爆的趨勢之一，特别是对年轻一代来说，自动化带来了许多变化。从历史与当前数据的角度，我们可以分析自动化对年轻一代的影响。
#         首先，我们可以从历史上看到自动化的发展趋势。根据“经济论文”杂志的文章[1]，我们可以看到，从1981年到1990年间，男性在这个时期内，无论是拥有高中、专技、大学等学历，相较于1960年前世代相同学历的初始条件薪酬，分别减少了34％、32％、50％。这种趋势继续到现代，年长或年轻世代，个人有较佳或较差之未观察到能力，都会导致初始条件薪酬相对偏高或偏低，同时有较高或较低的终身薪资成长。
#         其次，我们可以从当前数據中看到自动化对年轻一代的影响。根据“应用经济论叢”杂志的文章[2]，我们可以看到，在农业领域，新农保对农村老年人的勞動参与及工作时间产生了排擠效果，显著減少中老年人的工作时间，但没有显著影响中老年人的勞動参与。参加新农保的中老年人比没有参加新农保的中老年人年工作时间缩短了161个小时，对有工作者平均缩小了82个年工作小时，对60歲以上老年人缩小工作时间的幅度更大更显著。同时，新农保对农村老年人的勞動參與及工作時間之影響有延後現象，參保時間越久，對勞動供給的排擠效果越明顯。此外，對於男性、健康狀況較差，家庭經濟狀況較不好者，新农保對其工作時間的排擠效果更為明顯。
#         最后，我们还可以从 crossed-classified random effects model (CCREM)[3] 的应用中看到自动化对年轻一代的影响。CCREM可以帮助我们更准确地研究年龄、时期和出生世代之间的关联，并且可以处理多重共线性问题。从人口结构、市场机会和参与行为等几个维度来看，自动化给年轻一代带来了许多变化，但是这些变化的具体影响需要进一步研究。
#         总之，自动化是今天世界上一个热门趋势，对年轻一代来说，它带来了许多变化。从历史与当前数据的角度，我们可以看到自动化对年轻一代的影响包括初始条件薪酬的偏移、勞動供給的排擠效果等。但是，这些影响的具体程度和方向需要进一步研究。
#         注意：[1] Pi-Fem Hsu, “Terms of Intergenerational Income Inequality in Taiwan,” Economic Journal, vol. 49, no. 2, pp. 285-319.[2] Fung-Mey Huang, Xiao-Wan Ye, “New rural pension affects labor supply of the elderly in China: Evidence from CHARLS data,” Applied Economics Letters, vol. 108, no. 12, pp. 117-164.[3] Thung-Hong Lin, “Again exploring Taiwan’s generational politics: Cross-classified random effects models for age, period, and cohort effects, 1995-2010,” Social Sciences Quarterly, vol. 31, no. 4, pp. 555-599.
# 21.
# query: 假設你是一位經濟學領域的學者，請根據提供的的資料，請從貨幣政策的角度，分析其對國際合作的深遠影響。**請用繁體中文回答**
# keywords 貨幣政策 國際合作
# Final Answer:
# 您的回答：
#         在文件中，有幾篇文章探討了貨幣政策對國際合作的影響。這些文章主要从貨幣自主性、隔絕功能、匯率轉嫁等角度進行分析。
#         例如，Chen（1973）的自由匯率制度模型指出，當國外通貨膨脹率恰為某一定值或兩種通貨獨立无关时，自由匯率制度下貨幣政策效果的大小要视兩种通貨究竟是毛替代还是毛補充而定。这与Miles（1978）所说单憑通貨替代彈性的高低决定貨幣自主性的强弱不同。
#         另外，孫鈺峰和曹添旺（2008/12）的文章探討了名目匯率定錨政策的失敗，并认为通貨替代程度对此产生了影响。当通貨替代程度较高时，貨幣當局应采取大幅降低本國通貨貶值率来延后政策崩潰的時间，而当通貨替代程度较低时，貨幣當局应采取小幅度降低本國通貨貶值率来拖延政策崩潰发生的時間。

# query: 假設你是一位經濟學領域的學者，請根據提供的的資料，描述全球疫情在不同地區的應用，並分析其對經濟穩定的影響。**請用繁體中文回答**
# keywords 全球疫情 不同地區 經濟穩定
# Final Answer:
# 根據提供的文章，我們可以看到有幾篇文章討論了全球疫情對不同地區的應用和對經濟穩定的影響。
#         中國大陸研究的文章 «防疫與經濟發展:中國大陸政策目標矛盾下地方治理模式的多樣性» (Chang, Hung-yuan et al., 2021) 討論了中國大陸政府在疫情管控和經濟復工之間的折衷作法，這種折衷的作法使疫情更難控管，反而讓經濟穩定受損。
#         經濟論文叢刊的文章 «COVID-19大流行以來公衛與經濟相關學術文獻之擇要回顧» (Lai, Fu-Chuan et al., 2023) 檢視了COVID-19大流行以來的學術文獻，分析了公衛與經濟相關的話题，包括 early emergency allocation of medical resources, vaccine research and development, rich vs poor, city vs countryside, old people vs young people, and have money or power versus weak social groups.
#         中國大陸研究的文章 «疫情後兩岸經貿互動趨勢與供應鏈地位變化» (Liu, Meng-chun et al., 2022) 探討了疫情對兩岸貿易結構的影響，並使用社會網絡分析的「結構洞」和「點度中心性」等量化方法分析了兩岸在全球貿易網絡中的地位變化。
#         經濟論文的文章 «多次結構變動下趨勢穩定與差分穩定之認定—台灣總體資料實證研究» (Hsu, Chih-Chiang, 2001) 採用了 Taiwan computable general equilibrium model-dynamic (TAIGLM-D) 模型，進行了「事後」的經濟影響分析，探討了SARS疫情對臺灣總體經濟和個別產業的衝擊，並與「事前」預估模擬結果進行比較。
#         農業經濟叢刊的文章 «跨國CO2排放交易機制初始總量分配之檢視—不同公平準則下個別國家與世界整體之衝突與調和» (Liou, Je-Liang et al., 2010) 探討了不同公平準則下的跨國CO2排放交易機制初始總量分配的衝突與調和。
#         經濟研究的文章 «總體經濟變數對臺灣股市之大盤及類股熊市預測表現之探討» (Lee, Wei-Ming et al., 2015) 探討了總體經濟變數對臺灣加權股價指數與8 大類股股市熊市的預測力。
#         經濟論文的文章 «貿易自由化與所得不均度間之非單CALL關係» (Hsu, Tse-Chien, 2018) 探討了貿易自由化與所得不均度間的非單Call關係。
#         經濟論文的文章 «新興凱因斯學派總合供需模型下最適物價目標區之研究—以商品市場需求面干擾為例» (Liaw, Peir-Shyan and Wu, Chine-Hsing, 2021) 探討了在一個資本呈現不完全移動的浮動匯率小型開放經濟體系裡，當商品市場需求面遭逢隨機性衝擊時，貨幣當局物價目標區體制對相關的總體經濟變數是否具有穩定效果。
#         經濟論文的文章 «國際貿易、借貸市場摩擦與所得分配不平均」 (Hsu, Tse-Chien, 2014) 探討了貿易流量增加所带来的所得不均度，並使用產業內貿易模型和 borrowing market friction 等方法來解釋此現象。
#         經濟研究的文章 «股票市場波動對國民身體健康的衝擊」 (Guo, Zion and Sun, Zi-Yuan, 2020) 探討了股票市場波動對國民身體健康的影響。
#         總體而言，這些文章顯示了全球疫情在不同地區的應用及其對經濟穩定的影響。中國大陸政府在疫情管控和經濟復工之間的折衷作法使疫情更難控管，從而威脅經濟穩定。COVID-19大流行對公衛和經濟有着複雜的影響，包括疫苗研發成功但供應不足，富國與窮國、都市與鄉村、老年人與年輕人、有錢有權之人與弱勢族群之間的優先分配順序等。兩岸貿易結構被疫情所影響，而中东海在全球貿易網絡中的地位變化仍未確定。SARS疫情對台灣總體經濟和個別產業的影響被檢視，並與「事前」預估模擬結果進行比較。不同公平準則下的跨國CO2排放交易機制初始總量分配的衝突與調和被探討。總體經濟變數對台湾加權股價指數和八大股股市熊市的預測能力被探討。貿易自由化與所得不均度之間的非單call關係被探討。在一個資本呈現不完全移動的浮動匯率小型開放經濟體系裡，當商品市場需求面遭逢隨機性衝擊時，貨幣當局物價目標區體制對相關的總體經濟變數是否具有穩定效果被探討。貿易和借貸市場摩擦與所得分配不平均被探討。股票市場波動對國民身體健康的影響被探討。失業對個人薪資和健康的影響被探討。
# 24.
# query: 假設你是一位經濟學領域的學者，請根據提供的的資料，請從國際貿易的角度，分析其對企業成本結構的深遠影響。**請用繁體中文回答**
# keywords 國際貿易 企業成本結構
# Final Answer:
# 根据给定数据，从国际贸易的角度分析其对企业成本结构的深远影响。
#         如果文件中缺乏相关信息，请务必回复“信息不足”。另外，还不应创造不实存在的学术研究，仅提供真实存在的研究。
#         根據提供的資料，從國際貿易的角度分析其對企業成本結構的深遠影響。
#         如果文件中缺乏相關資訊，請務必回覆 “Information insufficient”。另外， still not create non-existent academic research, only provide real existing research.
#         根据给定数据，从国际贸易的角度分析其对企业成本结构的深远影响。
#         如果文件中缺乏相关信息，请务必回复 “Information insufficient”。另外，还不应创造不现实的学术研究，只提供实际存在的研究。
#
#         根據提供的內容，從國際貿易的角度分析其對企業成本結構的深遠影響。
#
#         首先，我們可以看到文中有些文章探討了不同方面的企業成本結構，例如，「從國際垂直分工的觀點探討台灣貿易的形态及其變動」(Chen, Hung-Yi, 2002)、「廠商異質性與進口報價幣別選擇:台灣的實證分析」(Lee, Yih-Chern et al., 2023)等文章。這些文章描述了不同方面的企業成本結構，包括生產成本、交易成本、資源成本等。
#
#         其次，我們可以看到文中有些文章探討了不同方面的國際貿易對企業成本結構的影響。例如，「環境政策與生產結構」(Chelsea C. Lin & Pei-Lin Chen, 2013)文章探討了環保政策對企業成本結構的影響，「運輸成本、資源和貿易量」(Deng-Shing Huang & Yo-Yi Huang, 2003)文章探討了運輸成本對企業成本結構的影響，「二氧化碳減量成本與策略：臺灣參與國際排放交易制度與密集度減量模式之意涵」(Tsung-Chen Lee et al., 2005)文章探討了二氧化碳減量成本對企業成本結構的影響等。
#
#         最後，我們可以看到文中有些文章探討了不同方面的企業成本結構對國際貿易的影響。例如，「從國際垂直分工的觀點探討台灣貿易的形态及其變動」(Chen, Hung-Yi, 2002)文章探討了企業成本結構對國際垂直分工的影響，「廠商異質性與進口報價幣別選擇:台灣的實證分析」(Lee, Yih-Chern et al., 2023)文章探討了企業成本結構對進口報價幣別選擇的影響，「環境政策與生產結構」(Chelsea C. Lin & Pei-Lin Chen, 2013)文章探討了企業成本結構對環保政策的影響等。
#
#
#         4. related literature or research findings to support the perspective:
#         1. Tzeng, C., & Huang, S.-F. (2013). The impact of social security policies on employment opportunities for foreign spouses in Taiwan. Journal of Social Science Research, 38(1), 111-132.
#          這文章探討了Foreign Spouse Employment Act (FSEA) 的影響，該法規允許外籍婚姻配偶在臺灣就業，並提供社會保險補助。 研究發現，FSEA 對外籍婚姻配偶的就業機會和生活品質有顯著的正面影響。
#
#         2. Hwang, W.-S., & Wu, J.-G. (2013). The effect of social insurance coverage on wage inequality between regular and irregular workers in Taiwan. Economic Research Quarterly, 26(3), 335-354.
#          這文章探討了社會保險對不規則勞工（irregular worker） 和規則勞工（regular worker）之間的薪資差異的影響。 研究發現，社會保險覆蓋對不規則勞工有顯著的正面影響，可以減少不規則勞工的薪資差異，並且可以促使不規則勞工進入正規勞工環境。
#
#         3. Chang, P.-C., & Lo, M.-C. (2012). Entrepreneurial performance and human capital development: Evidence from Taiwan. Small Business Economics, 38(1), 133-145.
#          這文章探討了人力資源（human capital） 對企業創新的影響。 研究發現，entrepreneurs with higher levels of human capital are more likely to start businesses that perform well, and they also tend to have better access to financial resources and networks than entrepreneurs with lower levels of human capital.
# 26.
# query: 假設你是一位經濟學領域的學者，請根據提供的的資料，描述氣候變化在不同地區的應用，並分析其對企業創新的影響。**請用繁體中文回答**
# keywords 氣態變化 企業創新 國家發展計劃
# Final Answer:
# 氣候變化是一個很複雜的問題，它對不同地区的影響也是不一樣的。根據提供的文章，我們可以看出，氣候變化對不同地區的應用和對企業創新的影響有所不同。
#         首先，氣候變化對農業地區的應用 mainly is in the form of temperature changes and precipitation patterns. For example, in some areas, warmer temperatures may lead to increased agricultural productivity, while in others, drought or excessive rainfall could harm crops. In addition, extreme weather events such as typhoons and heavy rains can cause significant damage to farmland and infrastructure. According to one study cited in the article, climate change could reduce global crop yields by up to 15% by 2050. This would have major implications for food security and prices, potentially leading to increased demand for new technologies and innovations to help farmers adapt to changing conditions.
#         在农业领域应用主要是温度变化和雨量模式。例如，某些地区热emperature会带来增加农产品生产，而其他地区则会导致干旱或过多雨 fall harm crops。同时，极端天气事件，如��ambe typhoons 和大雨，可对农场土地和基础设施造成显著损害。据一篇引用的文章所示，气候变化可能会减少全球农产量达到2050年的15%。这将对食物安全和价格带来重大影响，从而可能导致开发新技术和创新帮助农民适应变化条件的需求增加。
#         其次，氣候變化對城市地區的應用 main focus on energy production and consumption. For instance, rising temperatures can increase cooling demands, leading to higher electricity usage for air conditioning. At the same time, renewable energy sources like solar and wind power become more viable options due to improved weather conditions. The article discusses a case study of Tsinghua University's efforts to reduce its carbon footprint through energy efficiency improvements and the use of renewable energy. By implementing these measures, the university was able to save over $1 million per year in energy costs and significantly reduce its greenhouse gas emissions.
#          在城市地区应用的焦点在能源生产和消费上。例如，升温会增加冷房需求，导致空调电力使用增加。同时，可续用能源 source such as solar and wind power 成为更可行选择，由于改善的天气条件。文章介绍了清华大学采取能效改进和可续用能源使用方式来缩减碳足印的试验实施情况。通过执行这些措施，大学能每年节省超过一百万美元的能源成本并大大减少碳 Footprint。
#         最后，氣候變化對企業創新的影響 complex and multifaceted. On the one hand, it creates opportunities for innovation in industries such as agriculture, renewable energy, and water management. For example, companies are developing new irrigation systems that can better cope with drought conditions, or creating sensors that monitor soil moisture levels to optimize water usage. On the other hand, tue climate change also poses challenges for businesses, particularly those in sectors heavily reliant on fossil fuels. These firms may face increasing regulatory pressures and public scrutiny, as well as potential physical risks from extreme weather events.
#           最后，氣候變化對企業創新的影響是複雜且多方面的。一方面，它創造了機會，例如農業、可续用能源和水管理等行業的創新。例如，公司在旺季水欠的情況下開發新的灌溉系統，或創造能监测土壤濕度以优化水用量的传感器。另一方面，氣候變化對企業帶來了挑战，特别是那些密切依赖非燃Combustible fuels 的行業。這些企業面临增加的法令压力和公众关注，以及極端天气事件的物理風險。
#         在总结上，氣候變化對不同地區的應用和對企業創新的影響是不一樣的。在農業地區，氣候變化主要影響 agriculturally productive land, 而在城市地區則影響能源生產和消耗。氣候變化創造了機會，例如農業、可续用能源和水管理等行業的創新，同時也帶來了挑战，特別是那些密切依赖非燃 Combustible fuels 的行業。企業應該準備好面對這些挑战，並利用新技術和創新來應對氣候變化的影響。
# 27.
# query: 假設你是一位經濟學領域的學者，請根據提供的的資料，請根據貨幣政策的最新研究，探討其對非營利組織的多層次影響。**請用繁體中文回答**
# keywords 貨幣政策 非營利組織
# Final Answer:
# 您好！根據提供的文章，我們可以从貨幣政策对非營利組織的影響做以下分析：
#         首先，貨幣政策可以直接影響非營利組織的捐贈收入。例如，Resource and Development International Foundation etc. (2009) 的研究表明，資訊透明度及財務操縱程度對捐贈收入有正相關及負相關的影響。当资讯透明度高并财务操纵程度低时，组织获得的捐贈额较多。这种影响因素与控制变数方面，上述特性变数对非營利组织的捐款收入产生显著影響。
#         其次，貨幣政策可以间接影響非營利組織的經營活動。例如，Chen et al. (2016) 的研究表明，在經濟體系面臨商品需求面的干擾時，政府實施貨幣供給穩定政策，讓總產出水準保持在一定的範圍內，對非營利組織的經營活動產生了影響。
#         最后，貨幣政策也可以影響非營利組織的財政治治。例如，Lin and Lin (2020) 的研究表明，政府所宣示的未來國內信用擴張政策，可以主導經濟體系的相關總體經濟變數的調整。這些影響可以通過政策宣告、公部門聘僱、失業、貨幣政策等途徑實現。
#         總之，貨幣政策對非營利組織的影響是複雜的，可以直接影響捐贈收入、間接影響經營活動、及影響財政治治。這些影響可以通過資訊透明度、財務操縱程度、政府宣告、公部門聘僱、失業、貨幣政策等途徑實現。
# 28.
# query: 假設你是一位經濟學領域的學者，請根據提供的的資料，

# query: 假設你是一位經濟學領域的學者，請根據提供的的資料，從歷史與當前數據的角度，分析人類遷徙對農村人口的影響。**請用繁體中文回答**
# keywords 人類遷徙 農村人口
# Final Answer:
# 根據提供的資料，我們可以看到有幾篇文章探討了人類遷徙對農村人口的影響。首先，張慈佳等人的文章 («夢想的代價：區域間人口遷移決策之研究») 發現 dreaming pursuit variable 與其他影響 hrm migration variable 之間存在抵換效果，稱之為 «dreaming discount」，可用以衡量追尋夢想的代價。此結果顯示，人們的遷移決策確實可能受到非正式制度中的文化特性所影響。另一方面，马泰成的文章 («稻作经济下的创新与寻租») 強調，只要社會能夠摒棄文憑主义，避免教育与研发脫节，並提供经济誘因吸引社会精英选择創新，則少子化所導致的人口与动态减少，非但不会影響成长，甚至可能成为技术进步的动力。
#         從歷史上看，中國大陸研究的文章 («外来妹现象与大陆的跨省区结姻热») 描述了「外來妹現象」，該現象是由於中國經濟開放搞活、改變農村封閉狀態後，在一九八零年代末期才逐漸出現的新興事物。「外來妹」的原籍流入地大都比較遙遠，就流入女性言，一般為從西到東、從內陸到沿海的梯度流勢。大陸農民因婚姻關係遷移外省外地安家落戶，多少年來，創成了農村中持續不斷的人口流動。這一流動在客觀上對農村各地社區間的適婚人口性別比例發揮自我調節的作用，同時，婚姻流動在主觀上隱含了婚姻觀念背後的生活意願，也反映了農村社會變遷的趨勢。
#         從當前數據上看，許圣章等人的文章 («台湾农户资本与时间配置之分析») 發現，農家成員於農場內及農場外工作的時間配置呈現二元化的現象，農家成員高教育程度者大多從事農場外工作，而教育程度較低者則從事農場內的工作。農業收入函數估計顯示，農場內工作的教育報酬遠低於農場外教育報酬，此可解釋隨著農家下一代教育程度的提升，使得農家新一代青壯人口選擇轉移至報酬較高的非農業部門工作，而農家旧一代仍持續於農場工作，進而產生農家成員間時間配置近似二元分割的現象。
#         總之，從歷史與當前數據的角度來看，人類遷徙對農村人口的影響是複雜的，可能受到非正式制度、文化特性、教育報酬等因素的影響。
# 94.
# query: 假設你是一位經濟學領域的學者，請根據提供的的資料，從歷史與當前數據的角度，分析氣候變化對多國籍勞工的影響。**請用繁體中文回答**
# keywords 氣態變化 多國籍勞工
# Final Answer:
# 在這個問題中，提供的文章中似乎沒有直接討論氣態變化對多國籍勞工的影響，但是有幾篇文章討論了勞工的工作狀態和勞動市場的變化，這些變化可能會影響多國籍勞工的就業機率和薪資水平。以下是我對這個問題的分析：
#         首先，根據歷史上的研究，氣候變化對勞工的就業機率和薪資水平可能存在影響。例如，一项研究发现，美国历史上的气温变化对农业劳动力需求产生了显著影响，当温度上涨时，农业劳动力需求会减少，导致农业勞工失业率上涨，薪资水平则下跌。这种影响可能与多國籍勞工类别有区别，因为不同勞工组别在经济中起着不同的角色。例如，外籍勞工可能更敏感于经济条件的变化，因为他们通常没有永居权，因此他们的就业机会更依赖于经济状况。
#         从当前数據来看，也有证据表明氣候變化對勞工的影響存在。例如，一项研究发现，在美国东北部，氣候變化可能會影響建築勞工的就業機率和薪資水平。该研究发现，当夏天的雨量较少时，建築勞工的就业機率会上涨，薪资水平也会上漲。反之，当夏季雨量多时，建築勞工的就业機率会下跌，薪資水平也会下跌。这种影响可能与多國籍勞工有关，因为他们在建築行業中占据很大比例。
#         总之，虽然提供的文章中并没有直接討論氣態變化對多國籍勞工的影響，但是有幾篇文章描述了勞工的工作狀態和勞動市場的變化，這些變化可能會影響多國籍勞工的就業機率和薪資水平。以上分析仅是一个初步的探討，需要更多的研究才能確定氣態變化對多國籍勞工的真実影響。
# 95.
# query: 假設你是一位經濟學領域的學者，請根據提供的的資料，請分析最低工資政策如何影響企業高層，並總結政策建議。**請用繁體中文回答**
# keywords 最低工資政策 企業高層 政策建議
# Final Answer:
# 根据给予的数据，我们作为经济学专业的研究员，将分析最低工资政策对企业高层的影响，并总结政策建议。
#         首先，从论文[最低工资的分配效果]中可以看出，提高最低工资会导致低技术勞动工资增加，达到缩小高低技术勞动工资和勞动所得差距的目的。然而，在资本—技术不同互补性生产下，廠商以资本和高技術勞动来替代低技術勞动，进而推升资本报酬和高技術勞动的资本所得，造成高低技術总所得差距扩大。总体经济方面，提高最低工资能带动低技術勞动的消费，但是资本替代低技術勞动所引发的高失业率，对总消耗和产出产生不利影響。
#         其次，从文章[市场规模、廠商规模与城鄉失业]中可以看出，在市场规模扩张与最低工资率提高的条件下，大规模企业受益于市场规模的扩大，而小规模企业则受损。这种情况下，提高都会区的最低工资水准，可以提高就业人口数量，降低失业率。
#         综上所述，最低工资政策对企业高層的影响复杂，需要考虑到技术、规模和市场环境等因素。在实际政策设计时，应该优先考虑减轻企业负担的方法，例如降低企业所得税、减少注册费用等。同时，应该强化劳工训练和劳工福利，确保劳工拥有适当的技能和待遇，从而促进企业长期发展和劳工满意。
#         最后，还需要注意，上述分析仅基于给予的数据，实际情况可能会有所不同。因此，更详细的数据和研究是必要的，以便更精确地评估最低工资政策的影响和做出更佳的政策建议。
# 96.
# query: 假設你是一位經濟學領域的學者，請根據提供的的資料，請分析醫療保健體系如何影響移民工人，並總結政策建議。**請用繁體中文回答**
# keywords 醫療保健體系 移民工人 政策建議
# Final Answer:
# 隨著globalization和economic integration，移民工人 population has grown rapidly in many countries including Taiwan. The health of migrant workers is an important issue that needs to be addressed due to their vulnerability to various health risks. In this context, the analysis of healthcare systems' impact on migrant workers becomes crucial. Based on the provided data, I will discuss how healthcare systems affect migrant workers and propose policy recommendations.
#         首先，Let us examine the article titled 'Structural Vulnerabilities of a Mournful Song: The Daily Work and Health Experiences of Overseas Fishermen', which explores the daily work and health experiences of overseas fishermen from a structural perspective. This research reveals that political economic structures, culture, and bodily dynamics interactively shape the living conditions and health experiences of these workers. For instance, policies such as labor migration schemes can lead to long working hours, low wages, and poor working conditions, making it difficult for fishermen to access adequate healthcare services or afford them. Furthermore, cultural differences may hinder effective communication between medical staff and patients, leading to misdiagnosis or mistreatment. These findings highlight the importance of considering both macrostructural factors and microlevel interactions when studying the relationship between healthcare systems and migrant worker health.
#         其次，Another study entitled 'Two-sided Market Control Mechanisms Analysis of Service Trade Agreement "Personal Movement"" focuses on the regulatory mechanisms governing personal movement under service trade agreements. It compares the regulations regarding internal personnel transfers within multinational corporations and pledged persons under different free trade agreements. The results indicate that while Taiwan adheres to certain restrictions on Chinese mainland enterprise internal personnel and contractors, these limitations are relatively less stringent compared to those imposed by other six free trade agreements. Therefore, it is recommended that the government reconsider the current regulations concerning Chinese mainland enterprise internal personnel and contractors, aiming towards greater consistency with international standards.
#         第三，The paper 'Both sides of difference within difference: A comparative study of China's city community attitudes toward foreigners' examines the attitudes of Chinese city communities towards foreigners based on three dimensions: convenience, employment threat, and public service pressure. Using survey data collected in 2007, the authors find that social density and the concentration of foreigners in specific enterprises significantly influence community perceptions of employment threats posed by foreigners. Additionally, they discover that the more significant the presence of foreigners in a particular area, the stronger the perceived pressures on public services. However, if there is increased interaction between local residents and foreigners, the community feels more positively about the benefits brought by foreigners in terms of urban life conveniences. Overall, this study emphasizes the need for policymakers to consider both the potential challenges and opportunities presented by increasing diversity in order to create inclusive and supportive environments for all members of society.
#         最后，A study published in the Journal of Comparative Economics titled 'From Human Capital to Social Capital: Evidence from International Labor Markets' investigates the role of human capital and social capital in shaping labor market outcomes for immigrants. By analyzing data from multiple sources, the researchers reveal that immigrant human capital endowments have a positive effect on earnings growth but fail to account for the entire wage gap between natives and immigrants. Instead, social capital plays a vital role in explaining the remaining wage differential. Specifically, immigrants who build strong networks within their host country enjoy higher wages and better job prospects than those without such connections. Consequently, policies aimed at facilitating social capital formation among immigrant populations could help reduce wage disparities and promote upward mobility.
#         綜上所 mentioned studies demonstrate that healthcare systems, labor policies, and social interactions all play essential roles in influencing the health and wellbeing of migrant workers. To ensure equitable treatment and optimal health outcomes for this vulnerable population, governments should adopt comprehensive approaches that address both structural barriers and individual needs. Some possible policy recommendations include expanding affordable healthcare coverage, implementing labor protections against exploitation, promoting cross-cultural understanding and dialogue, and investing in programs designed to foster social capital development among immigrant communities. Ultimately, prioritizing the health and welfare of migrant workers not only contributes to their own well-being but also strengthens overall societal cohesion and resilience.
# 97.
# query: 假設你是一位經濟學領域的學者，請根據提供的的資料，請根據網絡安全的最新研究，探討其對跨國公司的多層次影響。**請用繁體中文回答**
# keywords 網絡安全 跨國公司 网络安全
# Final Answer:
# 您好！根據提供的文章，我們可以發現中國大陸政府在 recent years 建置了一套網路安全法規體系，這些法規包括《網絡安全法》、《個人信息保護法》和《關鍵信息基礎設施安全保護條例》等。這些法規主要是為了保護個人、企業和國家安全，並強化國家內的網路安全。
#         然而，這些法規也可能對跨國公司产生多層次的影響。首先，這些法規可能會增加成本，例如需要遵守更多的法規和規定，需要花費更多的資源來實施安全措施等。這些成本可能會影響cross-border M&A deals 和 cross-border investments，因為這些交易可能需要經過中國大陸的法規审批。
#         其次，這些法規可能會影響 cross-border data flows，因為中國大陸政府可能會要求外國企業將其数据存儲在中國大陸内，或者限制外國企业對中國大陸的網路访问。這可能會影響cross-border e-commerce和cloud computing services，因為这些服务可能需要经过中国大陆的网络访问。
#         最后，這些法規可能會影響 cross-border intellectual property rights，因為中國大陸政府可能會要求外國企業在中國大陸內获得許可才能使用其知识产权。這可能會影響cross-border licensing agreements和joint ventures。
#         总之，中國大陸的網路安全法規體系可能会对跨国公司产生多层次的影响，包括增加成本、影响数据流动和影响知识产权。
#         如果您需要更多信息，請告聞。
#         **請務必使用繁體中文回答。**
# 98.
# query: 假設你是一位經濟學領域的學者，請根據提供的的資料，描述數位化在不同地區的應用，並分析其對勞動力市場改善的影響。**請用繁體中文回答**
# keywords 數位化 地區應用 勞動力市場
# Final Answer:
# 根据给定数据，描述数字化在不同地区的应用以及对劳动力市场改善产生影响。
#         如果文档中没有相关信息，请务必回复“信息不足”。另外，也不要创造不存在的学术研究，仅提供实际存在的研究结果。
#
#         根據提供的資料，可見數位化在不同地區存在不同程度的應用，例如，行動裝置嵌入式應用軟件市場競爭分析文章描述了行動裝置的出現改變人類使用電腦的習慣，使得行動裝置嵌入式應用軟件發展蓬勃。此外，應用網路搜尋行為預測房地產市場文章顯示網際網路搜尋行為對房地產市場的影響，可以增強在不動產市場資訊或預估之即時掌握，提供政府擬定政策或企業、民眾決策時之參考。
#
#         在勞動力市場上，數位化可以幫助改善勞動力市場的效率和效果。例如，應用經濟論叢的文章 «台灣勞動市場附加工作者效果與怯志工作者效果之分析» 顯示，男性勞動力、國中及以下教育程度者、青年期與中年期勞動者等具怯志工作者效果，而女性勞動力、高中職教育程度者及壯年期勞動者則為附加工作者效果。此外，大專及以上教育程度者則符合失業不變假說觀點。這些結果顯示，數位化可以幫助 female workers to overcome the fear of job loss and be more willing to participate in the labor market, while also helping male workers with lower education levels or older ages to find better jobs that match their skills and abilities.
#
#         此外，中國大陸研究的文章 «改革開放後大陸勞動力市場情勢與就业政策» 還顯示，中共必須建立符合農村工業化和城市化方向，且具市場化的競爭就业制度和非歧視性勞動力市場，通過制定就對工資補貼等法規來規範勞動力市場。這些措施可以幫助改善中國勞動力市場的效率和效果，並幫助更多人获得良好的就业机会。
#
#         總之，數位化在不同地區存在不同程度的應用，並可以幫助改善勞動力市場的效率和效果。例如，行動裝置嵌入式應用軟件市場和網路搜尋行為预测房地产市场等技術可以提供更即时、精确的市场信息，帮助政府和企业做出更准确的决策。同时，通过建设符合農村工业化和城市化方向的竞争就业制度和非歧视性劳动力市场等措施，可以培养和培训更多人员，并为他们提供更好的就业机会。这将有利于改善劳动力市场的效率和效果，并促进经济发展。
# 99.
# query: 假設你是一位經濟學領域的學者，請根據提供的的資料，從企業社會責任政策的角度，分析其對貧富差距的潛在影響。**請用繁體中文回答**
# keywords 企業社會責任 貧富差距
# Final Answer:
# 您的回答應符合以下標準：
#         1. 清晰地描述研究背景和目的。
#         2. 針對提問所提供的文檔，分析企業社會責任政策的影響方向和程度。
#         3. 引用相關學術研究，並據实證結果。
#         4. 語言流暢，文字精細，符合學術書寫標準。
#
#         回答：
#         在今日經濟中，企業社會責任（Corporate Social Responsibility，CSR）已成為一個热门问题，尤其是与貧富差距密切相关。从文獻中可以发现，企业社会责任对貧富差距的影响方面存在着丰富的研究。
#         首先，陈香如等人（2022）的研究显示，企业社会责任表现与公司避税程序间存在互为因果的关系，公司的社会責任表現正向影響避稅程序，成本补偿假设成立，避稅程序正向影響社會責任表現，支持形象彌補假说。这种情况下，企业社會責任的强化将导致企業避稅行為减少，从而缩小貧富差距。
#         其次，张家榮等人（2024）的研究表明，当产品生产的边际污染较严重时，企业的友善环境行为确有益于改善环境品质和社会福利。这种情况下，企业社會責任的強化有利于減少貧富差距。
#         然而，王韋能等人（2021）的研究结果显示，企业社會責任支出对总体经济体系的影響是不確定的，而且透过数值模拟分析发现，企業社會責任支出增加對企業價值和社會福利均呈現先上升後下降的倒U字型效果，当企業社會責任支出比例不太高时，具有提高企業價值和社會福利的双重红利效果。但是，社會福利極大的企業社會責任支出比例超過企業價值極大的支出比例，使得社會福利極大更难以實現。
#         最后，戴华的文章（2016）探討我們和未來世代之間的道德關係，並強調我們對未來人類的道德責任，即“跨世代正義”的考量。在這種情況下，企業社會責任的強化對貧富差距的影響，將取決於企業社會責任的實現方式和方向。
#         總之，從企業社會責任政策的角度來看，企業社會責任的強化對貧富差距的影響是複雜的，需要考慮企業社會責任表現與避稅程序之間的互相影響，以及企業社會責任的實現方式和方向等因素。
#         相關文獻：
#         陳香如等，企業社會責任與租稅規避之關係：產品市場競爭的角色，《經濟研究》，58，2，339-385。
#         張家榮等，企業環境社會責任的福利分析－內生市場結構之影響，《農業經濟叢刊》，30，1，41-67。
#         王韋能等，從總體經濟的角度探討企業社會責任的效果，《經濟論文》，49，1，121-162。
#         戴華，我們和未來世代之間的道德關係：跨世代正義如何可能？，《臺灣經濟預測與政策》，46，2，159-184。
# 100.
# query: 假設你是一位經濟學領域的學者，請根據提供的的資料，描述自動化在不同地區的應用，並分析其對產業發展的影響。**請用繁體中文回答**
# keywords 自動化 產業發展 国内消费力趋势
# Final Answer:
# 根据给定数据，描述自动化在不同地区的应用，并分析其对产业发展的影响。
#         如果文档中没有相关信息，请务必回复“信息不足”。另外，还不允许创造不存在的学术研究，仅提供实际存在的。
#         根據提供的資料，描述自動化在不同地區的應用，並分析其對產業發展的影響。
#         如果所提供的資料中沒有相關信息，請回覆 “Information insufficient”。另外，還請 strictly avoid creating non-existent academic research, only provide actual existing ones.
#         根据给定数据，描述自动化在不同地区的应用以及其对产业发展的影响。
#         如果所提供的数据中没有相关信息，请回复“Data insufficient”。另外，严禁创造不存在的学术研究，只提供现实存在的。
#
#         根據提供的資料，自動化在不同地區都有應用，例如在台灣工具機業中，自動化技術的應用幫助提高生產力和效率，並使台灣工具機業成為世界第一的產業。此外，在中國大陸，自動化技術的應用幫助中國大陸產業轉型，使其從低成本生產國變成高技術產業國。在印度，自動化技術的應用幫助印度產業從手工製造向机械化和自动化转变，並幫助印度成為世界第七大economy。
#         根据给定数据，自动化在 Taiwanese tool industry 中广泛应用，帮助提高生产力和效率，使台湾工具机业成为世界第一个产业。同时，在中国大陆，自动化技术的应用帮助中国大陆产业从低成本生产国向高技术产业国转型。在印度，自动化技术的应用帮助印度产业从手工制造向机械化和自动化转变，并帮助印度成为世界第七大经济体。
#         根据给定数据，自动化在台湾工具机业中广泛应用，有助于提高生产力和效率，使台湾工具机业成为世界第一门产业。同时，在中国大陆，自动化技术的应用有助于中国大陆产业从低成本生产国向高技术产业国转型。在印度，自动化技术的应用有助于印度产业从手工制造向机械化和自动化转变，并有助于印度成为世界第七大经济体。
#         根据给定数据，自动化在台湾工具机业中广泛应用，有助于提高生产力和效率，使台湾工具机业成为世界第一门产业。同时，在中国大陆，自动化技术的应用有助于中国大陆产业从低成本生产国向高技术产业国转型。在印度，自动化技术的应用有助于印度产业从手工制造向机械化和自动化转变，并有助于印度成为世界第七大经济体。
#         根据给定数据，自动化在台湾工具机业中广泛应用，有助于提高生产力和效率，使台湾工具机业成为世界第一门产业。同时，在中国大陆，自动化技术的应用有助于中国大陆产业从低成本生产国向高技术产业国转型。在印度，自动化技术的应用有助于印度产业从手工制造向机械化和自动化转变，并有助于印度成为世界第七大经济体。
#         根据给定数据，自动化在台湾工具机业中广泛应用，有助于提高生产力和效率，使台湾工具机业成为世界第一门产业。同时，在中国大陆，自动化技术的应用有助于中国大陆产业从低成本生产国向高技术产业国转型。在印度，自动化技术的应用有助于印度产业从手工制造向机械化和自动化转变，并有助于印度成为世界第七大经济体。
#         根据给定数据，自动化在台湾工具机业中广泛应用，有助于提高生产力和效率，使台湾工具机业成为世界第一门产业。同时，在中国大陆，自动化技术的应用有助于中国大陆产业从低成本生产国向高技术产业国转型。在印度，自动化技术的应用有助于印度产业从手工制造向机械化和自动化转变，并有助于印度成为世界第七大经济体。
#         根据给定数据，自动化在台湾工具机业中广泛应用，有助于提高生产力和效率，使台湾工具机业成为世界第一门产业。同时，在中国大陆，自动化技术的应用有助于中国大陆产业从低成本生产国向高技术产业国转型。在印度，自动化技术的应用有助于印度产业从手工制造向机械化和自动化转变，并有助于印度成为世界第七大经济体。
#         根据给定数据，自动化在台湾工具机业中广泛应用，有助于提高生产力和效率，使台湾工具机业成为世界第一门产业。同时，在中国大陆，自动化技术的应用有助于中国大陆产业从低成本生产国向高技术产业国转型。在印度，自动化技术的应用有助于印度产业从手工制造向机械化和自动化转变，并有助于印度成为世界第七大经济体。
#         根据给定数据，自动化在台湾工具机业中广泛应用，有助于提高生产力和效率，使台湾工具机业成为世界第一门产业。同时，在中国大陆，自动化技术的应用有助于中国大陆产业从低成本生产国向高技术产业国转型。在印度，自动化技术的应用有助于印度产业从手工制造向机械化和自动化转变，并有助于印度成为世界第七大经济体。
#         根据给定数据，自动化在台湾工具机业中广泛应用，有助于提高生产力和效率，使台湾工具机业成为世界第一门产业。同时，在中国大陆，自动化技术的应用有助于中国大陆产业从低成本生产国向高技术产业国转型。在印度，自动化技术的应用有助于印度产业从手工制造向机械化和自动化转变，并有助于印度成为世界第七大经济体。
#         根据给定数据，自动化在台湾工具机业中广泛应用，有助于提高生产力和效率，使台湾工具机业成为世界第一门产业。同时，在中国大陆，自动化技术的应用有助于中国大陆产业从低成本生產國向高技術產業國轉型。在印度，自動化技術的應用有助於印度產業從手工製造向機械化和自動化轉變，並有助於印度成為世界第七大經濟體。
#         根据给定数据，自动化在台湾工具机业中广泛应用，有助于提高生产力和效率，使台湾工具机业成为世界第一门产业。同时，在中国大陆，自动化技术的应用有助于中国大陆产业从低成本生產國向高技術產業國轉型。在印度，自動化技術的應用有助於印度產業從手工製造向機械化和自動化轉變，並有助於印度成為世界第七大經濟體。
#         根据给定数据，自动化在台湾工具机业中广泛应用，有助于提高生产力和效率，使台湾工具机业成为世界第一门产业。同时，在中国大陆，自动化技术的应用有助于中国大陆产业从低成本生產國向高技術產業國轉型。在印度，自動化技術的應用有助於印度產業從手工製造向機械化和自動化轉變，並有助於印度成為世界第七大經濟體。
#         根据给定数据，自动化在台湾工具机业中广泛应用，有助于提高生产力和效率，使台湾工具机业成为世界第一门产业。同时，在中国大陆，自动化技术的应用有助于中国大陆产业从低成本生產國向高技術產業國轉型。在印度，自動化技術的應用有助於印度產業從手工製造向機械化和自動化轉變，並有助於印度成為世界第七大經濟體。
#         根据给定数据，自动化在台湾工具机业中广泛应用，有助于提高生产力和效率，使台湾工具机业成为世界第一门产业。同时，在中国大陆，自动化技术的应用有助于中国大陆产业从低成本生產國向高技術產業國轉型。在印度，自動化技術的應用有助於印度產業從手工製造向機械化和自動化轉變，並有助於印度成為世界第七大經濟體。
#         根据给定数据，自动化在台湾工具机业中广泛应用，有助于提高生产力和效率，使台湾工具机业成为世界第一门产业。同时，在中国大陆，自动化技术的应用有助于中国大陆产业从低成本生產國向高技術產業國轉型。在印度，自動化技術的應用有助於印度產業從手工製造向機械化和自動化轉變，並有助於印度成為世界第七大經濟體。
#         根据给定数据，自动化在台湾工具机业中广泛应用，有助于提高生产力和效率，使台湾工具机业成为世界第一门产业。同时，在中国大陆，自动化技术的应用有助于中国大陆产业从低成本生產國向高技術產業國转型。在印度，自動化技術的應用有助於印度產業從手工製造向機械化和自動化轉變，並有助於印度成為世界第七大經濟體。
#         根据给定数据，自动化在台湾工具机业中广泛应用，有助于提高生产力和效率，使台湾工具机业成为世界第一门产业。同时，在中国大陆，自动化技术的应用有助于中国大陆产业从低成本生產國向高技術產業國转型。在印度，自動化技術的應用有助於印度產業從手工製造向機械化和自動化轉變，並有助於印度成為世界第七大經濟體。
#         根据给定数据，自动化在台湾工具机业中广泛应用，有助于提高生产力和效率，使台湾工具机业成为世界第一门产业。同时，在中国大陆，自动化技术的应用有助于中国大陆产业从低成本生產國向高技術產業國转型。在印度，自動化技術的應用有助於印度產業從手工製造向機械化和自動化轉變，並有助於印度成為世界第七大經濟體。
#         根据给定数据，自动化在台湾工具机业中广泛应用，有助于提高生产力和效率，使台湾工具机业成为世界第一门产业。同时，在中国大陆，自动化技术的应用有助于中国大陆产业从低成本生產國向高技術產業國转型。在印度，自動化技術的應用有助於印度產業從手工製造向機械化和自動化轉變，并有助於印度成為世界第七大經濟體。
#         根据给定数据，自动化在台湾工具机业中广泛应用，有助于提高生产力和效率，使台湾工具机业成为世界第一门产业。同时，在中国大陆，自动化技术的应用有助于中国大陆产业从低成本生產國向高技術產業國轉型。在印度，自動化技術的應用有助於印度產業從手工製造向機械化和自動化轉變，並有助於印度成為世界第七大經濟體。
#         根据给定数据，自动化在台湾工具机业中广泛应用，有助于提高生产力和效率，使台湾工具机业成为世界第一门产业。同时，在中国大陆，自动化技术的应用有助于中国大陆产业从低成本生產國向高技術產業國轉型。在印度，自動化技術的應用有助於印度產業從手工製造向機械化和自動化轉變，並有助於印度成為世界第七大經濟體。
#         根据给定数据，自动化在台湾工具机业中广泛应用，有助于提高生产力和效率，使台湾工具机业成为世界第一门产业。同时，在中国大陆，自动化技术的应用有助于中国大陆产业从低成本生產國向高技術產業國轉型。在印度，自動化技術的應用有助於印度產業從手工製造向機械化和自動化轉變，並有助於印度成為世界第七大經濟體。
#         根据给定数据，自动化在台湾工具机业中广泛应用，有助于提高生产力和效率，使台湾工具

# %%
faithfulness_scores = []
for i in range(len(querys)):    
    score = calculate_faithfulness_score(retrieved_contents[i], querys[i], responses[i])
    faithfulness_scores.append(score)
    if (i + 1) % 5 == 0:
        print(f"{i + 1} questions are done!")

# %%
for i, score in enumerate(faithfulness_scores, start=1):
    print(f"問題 {i} 的 faithfulness_scores：{score}")
# Out:
# 問題 1 的 faithfulness_scores：1.0
# 問題 2 的 faithfulness_scores：0.875
# 問題 3 的 faithfulness_scores：1.0
# 問題 4 的 faithfulness_scores：1.0
# 問題 5 的 faithfulness_scores：0.6
# 問題 6 的 faithfulness_scores：0.792
# 問題 7 的 faithfulness_scores：0.882
# 問題 8 的 faithfulness_scores：0.917
# 問題 9 的 faithfulness_scores：0.0
# 問題 10 的 faithfulness_scores：1.0
# 問題 11 的 faithfulness_scores：1.0
# 問題 12 的 faithfulness_scores：0.4
# 問題 13 的 faithfulness_scores：0.471
# 問題 14 的 faithfulness_scores：1.0
# 問題 15 的 faithfulness_scores：1.0
# 問題 16 的 faithfulness_scores：0.529
# 問題 17 的 faithfulness_scores：0.25
# 問題 18 的 faithfulness_scores：0.833
# 問題 19 的 faithfulness_scores：0.909
# 問題 20 的 faithfulness_scores：0.576
# 問題 21 的 faithfulness_scores：0.667
# 問題 22 的 faithfulness_scores：1.0
# 問題 23 的 faithfulness_scores：1.0
# 問題 24 的 faithfulness_scores：0.889
# 問題 25 的 faithfulness_scores：1.0
# 問題 26 的 faithfulness_scores：1.0
# 問題 27 的 faithfulness_scores：0.941
# 問題 28 的 faithfulness_scores：0.8
# 問題 29 的 faithfulness_scores：0.5
# 問題 30 的 faithfulness_scores：1.0
# 問題 31 的 faithfulness_scores：0.941
# 問題 32 的 faithfulness_scores：0
# 問題 33 的 faithfulness_scores：0.812
# 問題 34 的 faithfulness_scores：0.222
# 問題 35 的 faithfulness_scores：0.929
# 問題 36 的 faithfulness_scores：0.75
# 問題 37 的 faithfulness_scores：0.654
# 問題 38 的 faithfulness_scores：0.917
# 問題 39 的 faithfulness_scores：0.909
# 問題 40 的 faithfulness_scores：1.0
# 問題 41 的 faithfulness_scores：0.318
# 問題 42 的 faithfulness_scores：0.6
# 問題 43 的 faithfulness_scores：0.929
# 問題 44 的 faithfulness_scores：0.857
# 問題 45 的 faithfulness_scores：1.0
# 問題 46 的 faithfulness_scores：0.846
# 問題 47 的 faithfulness_scores：0.5
# 問題 48 的 faithfulness_scores：1.0
# 問題 49 的 faithfulness_scores：0.933
# 問題 50 的 faithfulness_scores：1.0
# 問題 51 的 faithfulness_scores：0.615
# 問題 52 的 faithfulness_scores：0.364
# 問題 53 的 faithfulness_scores：0.842
# 問題 54 的 faithfulness_scores：0.5
# 問題 55 的 faithfulness_scores：1.0
# 問題 56 的 faithfulness_scores：0.952
# 問題 57 的 faithfulness_scores：0.933
# 問題 58 的 faithfulness_scores：0.875
# 問題 59 的 faithfulness_scores：0.12
# 問題 60 的 faithfulness_scores：1.0
# 問題 61 的 faithfulness_scores：1.0
# 問題 62 的 faithfulness_scores：0.8
# 問題 63 的 faithfulness_scores：1.0
# 問題 64 的 faithfulness_scores：0.3
# 問題 65 的 faithfulness_scores：0
# 問題 66 的 faithfulness_scores：0.318
# 問題 67 的 faithfulness_scores：0.963
# 問題 68 的 faithfulness_scores：1.0
# 問題 69 的 faithfulness_scores：0.194
# 問題 70 的 faithfulness_scores：0.923
# 問題 71 的 faithfulness_scores：0.947
# 問題 72 的 faithfulness_scores：0.556
# 問題 73 的 faithfulness_scores：0.727
# 問題 74 的 faithfulness_scores：0.867
# 問題 75 的 faithfulness_scores：0.7
# 問題 76 的 faithfulness_scores：1.0
# 問題 77 的 faithfulness_scores：0.786
# 問題 78 的 faithfulness_scores：0.75
# 問題 79 的 faithfulness_scores：1.0
# 問題 80 的 faithfulness_scores：0.667
# 問題 81 的 faithfulness_scores：0.4
# 問題 82 的 faithfulness_scores：0.35
# 問題 83 的 faithfulness_scores：0.318
# 問題 84 的 faithfulness_scores：1.0
# 問題 85 的 faithfulness_scores：0.938
# 問題 86 的 faithfulness_scores：0.941
# 問題 87 的 faithfulness_scores：0.0
# 問題 88 的 faithfulness_scores：1.0
# 問題 89 的 faithfulness_scores：0.857
# 問題 90 的 faithfulness_scores：0.0
# 問題 91 的 faithfulness_scores：0.944
# 問題 92 的 faithfulness_scores：1.0
# 問題 93 的 faithfulness_scores：0.955
# 問題 94 的 faithfulness_scores：0.0
# 問題 95 的 faithfulness_scores：0.263
# 問題 96 的 faithfulness_scores：1.0
# 問題 97 的 faithfulness_scores：1.0
# 問題 98 的 faithfulness_scores：1.0
# 問題 99 的 faithfulness_scores：0.733
# 問題 100 的 faithfulness_scores：1.0

# %%
print(sum(faithfulness_scores)/len(faithfulness_scores))
# Out:
# 0.74346

# %% [markdown]
# ### test answer_relevance

# %%
answer_relevance_scores = []
for i in range(len(responses)):
    pred_questions = question_generation(responses[i])
    score = calculate_answer_relevance_score(querys[i], pred_questions.content)
    answer_relevance_scores.append(score)
    if (i + 1) % 5 == 0:
        print(f"{i + 1} questions are done!")
# Out:
# 5 questions are done!
# 10 questions are done!
# 15 questions are done!
# 20 questions are done!
# 25 questions are done!
# 30 questions are done!
# 35 questions are done!
# 40 questions are done!
# 45 questions are done!
# 50 questions are done!
# 55 questions are done!
# 60 questions are done!
# 65 questions are done!
# 70 questions are done!
# 75 questions are done!
# 80 questions are done!
# 85 questions are done!
# 90 questions are done!
# 95 questions are done!
# 100 questions are done!

# %%
for i, score in enumerate(answer_relevance_scores, start=1):
    print(f"Question {i} answer_relevance score: {round(score, 3)}")
# Out:
# Question 1 answer_relevance score: 0.927
# Question 2 answer_relevance score: 0.931
# Question 3 answer_relevance score: 0.912
# Question 4 answer_relevance score: 0.883
# Question 5 answer_relevance score: 0.883
# Question 6 answer_relevance score: 0.95
# Question 7 answer_relevance score: 0.91
# Question 8 answer_relevance score: 0.93
# Question 9 answer_relevance score: 0.921
# Question 10 answer_relevance score: 0.94
# Question 11 answer_relevance score: 0.928
# Question 12 answer_relevance score: 0.945
# Question 13 answer_relevance score: 0.927
# Question 14 answer_relevance score: 0.946
# Question 15 answer_relevance score: 0.917
# Question 16 answer_relevance score: 0.902
# Question 17 answer_relevance score: 0.923
# Question 18 answer_relevance score: 0.843
# Question 19 answer_relevance score: 0.95
# Question 20 answer_relevance score: 0.922
# Question 21 answer_relevance score: 0.915
# Question 22 answer_relevance score: 0.934
# Question 23 answer_relevance score: 0.932
